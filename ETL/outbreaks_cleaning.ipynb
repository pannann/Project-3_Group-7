# %%
import pandas as pd

# %%
#Load csv files into dataframes
df_2016 = pd.read_csv('Resources/ob_report_2016.csv')
df_2017 = pd.read_csv('Resources/ob_report_2017.csv')
df_2018 = pd.read_csv('Resources/ob_report_2018.csv')
df_2019 = pd.read_csv('Resources/ob_report_2019.csv')
df_2020 = pd.read_csv('Resources/ob_report_2020.csv')
df_2021 = pd.read_csv('Resources/ob_report_2021.csv')
df_2022 = pd.read_csv('Resources/ob_report_2022.csv')
df_2023 = pd.read_csv('Resources/ob_report_2023.csv')

# %%
#Check total number of rows
print(len(df_2016) + len(df_2017) + len(df_2018) + len(df_2019) + len(df_2020) + len(df_2021) + len(df_2022) + len(df_2023))
# Out:
# 4362

# %%
#Rename 'Causative Agent-1' and 'Causative Agent-2' columns from df_2020 to match all other years
df_2020 = df_2020.rename(columns = {'Causative Agent - 1': 'Causative Agent-1',
                                                                                    'Causative Agent - 2': 'Causative Agent-2'})
df_2020.columns
# Out:
# Index(['_id', 'Institution Name', 'Institution Address', 'Outbreak Setting',
#        'Type of Outbreak', 'Causative Agent-1', 'Causative Agent-2',
#        'Date Outbreak Began', 'Date Declared Over', 'Active'],
#       dtype='object')

# %%
#Use pd.concat to combine all 7 DFs together
df_all = pd.concat([df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023], axis = 0, ignore_index = True)
df_all
# Out:
#       _id                                   Institution Name  \
# 0       1                           Extendicare Rouge Valley
# 1       2                       Michael Garron Hospital - H6
# 2       3                             Bendale Acres - 3rd Fl
# 3       4  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...
# 4       5                           Amica At Bayview Gardens
# ...   ...                                                ...
# 4357  883    Isabel and Arthur Meighen Manor - Lawrence Unit
# 4358  884  North York General Hospital - Branson Site - 4...
# 4359  885  Sunnybrook Health Sciences Centre - Sunnybrook...
# 4360  886  Sunnybrook Health Sciences Centre - Sunnybrook...
# 4361  887  Villa Colombo Homes For The Aged - 5 Fusco Sou...
#
#         Institution Address       Outbreak Setting Type of Outbreak  \
# 0            551 Conlins Rd                   LTCH      Respiratory
# 1           825 Coxwell Ave    Hospital-Acute Care          Enteric
# 2       2920 Lawrence Ave E                   LTCH      Respiratory
# 3         3555 Danforth Ave                   LTCH      Respiratory
# 4                19 Rean Dr        Retirement Home      Respiratory
# ...                     ...                    ...              ...
# 4357        155 Millwood Rd                   LTCH      Respiratory
# 4358  555 Finch Avenue West  Hospital-Chronic Care      Respiratory
# 4359       2075 Bayview Ave                   LTCH      Respiratory
# 4360       2075 Bayview Ave                   LTCH      Respiratory
# 4361        40 Playfair Ave                   LTCH      Respiratory
#
#                 Causative Agent-1            Causative Agent-2  \
# 0              Influenza A (H3N2)                          NaN
# 1                  Norovirus-like                          NaN
# 2     Respiratory syncytial virus                          NaN
# 3                 Metapneumovirus                          NaN
# 4                Influenza A (H3)                          NaN
# ...                           ...                          ...
# 4357                     COVID-19                          NaN
# 4358                     COVID-19                          NaN
# 4359                     COVID-19                          NaN
# 4360                     COVID-19                          NaN
# 4361   Influenza A (Not subtyped)  Respiratory syncytial virus
#
#      Date Outbreak Began Date Declared Over Active
# 0             2016-12-31         2017-01-20      N
# 1             2016-12-30         2017-01-04      N
# 2             2016-12-30         2017-01-13      N
# 3             2016-12-30         2017-01-20      N
# 4             2016-12-30         2017-01-20      N
# ...                  ...                ...    ...
# 4357          2023-01-01         2023-02-21      N
# 4358          2023-01-01         2023-01-14      N
# 4359          2023-01-01         2023-01-18      N
# 4360          2023-01-01         2023-01-16      N
# 4361          2023-01-01         2023-01-13      N
#
# [4362 rows x 10 columns]

# %%
#Check DF for missing fields or null values
df_all.info()
#Some missing values in 'Date Declared Over' for currently active outbreaks
#Causative Agent-2 has over 4000 null rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  4362 non-null   int64
#  1   Institution Name     4362 non-null   object
#  2   Institution Address  4362 non-null   object
#  3   Outbreak Setting     4362 non-null   object
#  4   Type of Outbreak     4362 non-null   object
#  5   Causative Agent-1    4362 non-null   object
#  6   Causative Agent-2    241 non-null    object
#  7   Date Outbreak Began  4362 non-null   object
#  8   Date Declared Over   4280 non-null   object
#  9   Active               4362 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 340.9+ KB

# %%
#Drop Causative Agent-2 and rename Causative Agent-1 to Causative Agent
df_all = df_all.drop('Causative Agent-2', axis = 1)
df_all = df_all.rename(columns = {'Causative Agent-1': 'Causative Agent'})
df_all.head()
# Out:
#    _id                                   Institution Name  \
# 0    1                           Extendicare Rouge Valley
# 1    2                       Michael Garron Hospital - H6
# 2    3                             Bendale Acres - 3rd Fl
# 3    4  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...
# 4    5                           Amica At Bayview Gardens
#
#    Institution Address     Outbreak Setting Type of Outbreak  \
# 0       551 Conlins Rd                 LTCH      Respiratory
# 1      825 Coxwell Ave  Hospital-Acute Care          Enteric
# 2  2920 Lawrence Ave E                 LTCH      Respiratory
# 3    3555 Danforth Ave                 LTCH      Respiratory
# 4           19 Rean Dr      Retirement Home      Respiratory
#
#                Causative Agent Date Outbreak Began Date Declared Over Active
# 0           Influenza A (H3N2)          2016-12-31         2017-01-20      N
# 1               Norovirus-like          2016-12-30         2017-01-04      N
# 2  Respiratory syncytial virus          2016-12-30         2017-01-13      N
# 3              Metapneumovirus          2016-12-30         2017-01-20      N
# 4             Influenza A (H3)          2016-12-30         2017-01-20      N

# %%
#Change Active column to Status, Y to Active and N to Inactive
renamed_active_values = {'Y': 'Active', 'N': 'Inactive'}
df_all = df_all.rename(columns = {'Active': 'Outbreak Status'})
df_all['Outbreak Status'] = df_all['Outbreak Status'].replace(renamed_active_values)
df_all.head()
# Out:
#    _id                                   Institution Name  \
# 0    1                           Extendicare Rouge Valley
# 1    2                       Michael Garron Hospital - H6
# 2    3                             Bendale Acres - 3rd Fl
# 3    4  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...
# 4    5                           Amica At Bayview Gardens
#
#    Institution Address     Outbreak Setting Type of Outbreak  \
# 0       551 Conlins Rd                 LTCH      Respiratory
# 1      825 Coxwell Ave  Hospital-Acute Care          Enteric
# 2  2920 Lawrence Ave E                 LTCH      Respiratory
# 3    3555 Danforth Ave                 LTCH      Respiratory
# 4           19 Rean Dr      Retirement Home      Respiratory
#
#                Causative Agent Date Outbreak Began Date Declared Over  \
# 0           Influenza A (H3N2)          2016-12-31         2017-01-20
# 1               Norovirus-like          2016-12-30         2017-01-04
# 2  Respiratory syncytial virus          2016-12-30         2017-01-13
# 3              Metapneumovirus          2016-12-30         2017-01-20
# 4             Influenza A (H3)          2016-12-30         2017-01-20
#
#   Outbreak Status
# 0        Inactive
# 1        Inactive
# 2        Inactive
# 3        Inactive
# 4        Inactive

# %%
#Drop the '_id' column as there are some duplicates from the original DFs
df_all = df_all.drop('_id', axis = 1)
df_all.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory           Influenza A (H3N2)
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory             Influenza A (H3)
#
#   Date Outbreak Began Date Declared Over Outbreak Status
# 0          2016-12-31         2017-01-20        Inactive
# 1          2016-12-30         2017-01-04        Inactive
# 2          2016-12-30         2017-01-13        Inactive
# 3          2016-12-30         2017-01-20        Inactive
# 4          2016-12-30         2017-01-20        Inactive

# %%
#Check if any dtypes need to be converted
df_all.dtypes
# Out:
# Institution Name       object
# Institution Address    object
# Outbreak Setting       object
# Type of Outbreak       object
# Causative Agent        object
# Date Outbreak Began    object
# Date Declared Over     object
# Outbreak Status        object
# dtype: object

# %%
#Change Date Outbreak Began and Date Outbreak Over to datetime objects
df_all['Date Outbreak Began'] = pd.to_datetime(df_all['Date Outbreak Began'], format = '%Y-%m-%d')
df_all['Date Declared Over'] = pd.to_datetime(df_all['Date Declared Over'], format = '%Y-%m-%d')
df_all.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory           Influenza A (H3N2)
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory             Influenza A (H3)
#
#   Date Outbreak Began Date Declared Over Outbreak Status
# 0          2016-12-31         2017-01-20        Inactive
# 1          2016-12-30         2017-01-04        Inactive
# 2          2016-12-30         2017-01-13        Inactive
# 3          2016-12-30         2017-01-20        Inactive
# 4          2016-12-30         2017-01-20        Inactive

# %%
#Check dtypes again
df_all.dtypes
# Out:
# Institution Name               object
# Institution Address            object
# Outbreak Setting               object
# Type of Outbreak               object
# Causative Agent                object
# Date Outbreak Began    datetime64[ns]
# Date Declared Over     datetime64[ns]
# Outbreak Status                object
# dtype: object

# %%
#Check Type of Outbreak values
print(df_all['Type of Outbreak'].unique())
print(df_all['Type of Outbreak'].value_counts())
# Out:
# ['Respiratory' 'Enteric' 'Other']
# Respiratory    3999
# Enteric         348
# Other            15
# Name: Type of Outbreak, dtype: int64

# %%
#Check Causative Agent values
df_all['Causative Agent'].unique()
# Out:
# array(['Influenza A (H3N2)', 'Norovirus-like',
#        'Respiratory syncytial virus', 'Metapneumovirus',
#        'Influenza A (H3)', 'Unable to identify',
#        'Influenza A (Not subtyped)', 'Coronavirus', 'Rhinovirus',
#        'Parainfluenza type 1', 'Enterovirus/Rhinovirus',
#        'Clostridium difficile', 'Parainfluenza type 3',
#        'Shigella flexneri (Group B)', 'Influenza B',
#        'Influenza A ((H1N1)pdm09)', 'Streptococcus pyogenes',
#        'Parainfluenza type 2', 'Parainfluenza type 4',
#        'Parainfluenza Type 1', 'Adenovirus',
#        'Clostridium difficile (Toxin B)', 'Rhinovirus, Coronavirus',
#        'Influenza A (H1N1)', 'CPE - Colonization',
#        'Clostridium difficile (Toxin A & B)',
#        'Influenza A (H3), Parainfluenza type 2', 'Influenza A and B',
#        'Influenza A (H3), Parainfluenza type 1', 'Influenza A (H1)',
#        'Parainfluenza virus', '(CPE) - Infection - (KPC)',
#        '(CPE) - Infection - (VIM)', '(CPE) - Unspecified (NDM)',
#        '(CPE) - Colonization (KPC)', 'COVID-19', 'Coronavirus*',
#        'Parainfluenza', 'Rotavirus', 'Pending',
#        'Parainfluenza UNSPECIFIED', 'Enterovirus',
#        'Campylobacter unspecified', 'Campylobacter jejuni',
#        'CPE Unspecified (NDM)', 'CPE Unspecified (VIM)',
#        'Group B Streptococcal disease (neonatal)', 'Norovirus',
#        'Parainfluenza PIV III', 'CPE Enterobacter unspecified (NDM)',
#        'CPE Unspecified (KPC)'], dtype=object)

# %%
#Recategorive Causative Agent for readability and simplicity
causative_agents = {'Influenza A (H3N2)': 'Influenza A', 'Influenza A (H3)': 'Influenza A', 'Influenza A (Not subtyped)': 'Influenza A',
                    'Parainfluenza type 1': 'Parainfluenza', 'Parainfluenza type 3': 'Parainfluenza', 'Shigella flexneri (Group B)': 'Shigella flexneri',
                    'Influenza A ((H1N1)pdm09)': 'Influenza A', 'Parainfluenza type 2': 'Parainfluenza', 'Parainfluenza type 4': 'Parainfluenza',
                    'Parainfluenza Type 1': 'Parainfluenza', 'Clostridium difficile (Toxin B)': 'Clostridium difficile', 'Influenza A (H1N1)': 'Influenza A',
                    'CPE - Colonization': 'CPE', 'Clostridium difficile (Toxin A & B)': 'Clostridium difficile', 'Influenza A (H3), Parainfluenza type 2': 'Influenza A and Parainfluenza',
                    'Influenza A (H3), Parainfluenza type 1': 'Influenza A and Parainfluenza', 'Influenza A (H1)': 'Influenza', 'Parainfluenza virus': 'Parainfluenza',
                    '(CPE) - Infection - (KPC)': 'CPE', '(CPE) - Infection - (VIM)': 'CPE', '(CPE) - Unspecified (NDM)': 'CPE', '(CPE) - Colonization (KPC)': 'CPE',
                    'COVID-19': 'Coronavirus', 'Coronavirus*': 'Coronavirus', 'Parainfluenza UNSPECIFIED': 'Parainfluenza', 'CPE Unspecified (NDM)': 'CPE',
                    'CPE Unspecified (VIM)': 'CPE', 'Parainfluenza PIV III': 'Parainfluenza', 'CPE Enterobacter unspecified (NDM)': 'CPE', 'CPE Unspecified (KPC)': 'CPE',
                    'Pending': 'Unable to identify'}
df_all['Causative Agent'] = df_all['Causative Agent'].replace(causative_agents)
df_all.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status
# 0          2016-12-31         2017-01-20        Inactive
# 1          2016-12-30         2017-01-04        Inactive
# 2          2016-12-30         2017-01-13        Inactive
# 3          2016-12-30         2017-01-20        Inactive
# 4          2016-12-30         2017-01-20        Inactive

# %%
#Check Causative Agent values again
df_all['Causative Agent'].unique()
# Out:
# array(['Influenza A', 'Norovirus-like', 'Respiratory syncytial virus',
#        'Metapneumovirus', 'Unable to identify', 'Coronavirus',
#        'Rhinovirus', 'Parainfluenza', 'Enterovirus/Rhinovirus',
#        'Clostridium difficile', 'Shigella flexneri', 'Influenza B',
#        'Streptococcus pyogenes', 'Adenovirus', 'Rhinovirus, Coronavirus',
#        'CPE', 'Influenza A and Parainfluenza', 'Influenza A and B',
#        'Influenza', 'Rotavirus', 'Enterovirus',
#        'Campylobacter unspecified', 'Campylobacter jejuni',
#        'Group B Streptococcal disease (neonatal)', 'Norovirus'],
#       dtype=object)

# %%
#Export df_all to a CSV file
df_all.to_csv('Resources/outbreaks_cleaned_2016_2023.csv')

# %% [markdown]
# ## GeoApify Address Autocomplete API

# %%
#Check DF
df_all.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status
# 0          2016-12-31         2017-01-20        Inactive
# 1          2016-12-30         2017-01-04        Inactive
# 2          2016-12-30         2017-01-13        Inactive
# 3          2016-12-30         2017-01-20        Inactive
# 4          2016-12-30         2017-01-20        Inactive

# %%
#Store full institution addresses in a list
inst_addresses = list(df_all['Institution Address'].unique())
inst_addresses
# Out:
# ['551 Conlins Rd',
#  '825 Coxwell Ave',
#  '2920 Lawrence Ave E',
#  '3555 Danforth Ave',
#  '19 Rean Dr',
#  '67 Belgreen Ave',
#  '2 Buchan Crt',
#  '429 Walmer Rd',
#  '1 Bridgepoint Dr',
#  '3276 St Clair Ave E',
#  '82 Buttonwood Ave',
#  '2075 Bayview Ave',
#  '495 The West Mall',
#  '40 Bell Estate Rd',
#  '130 Midland Ave',
#  '30 The Queensway',
#  '1195 Queen St E',
#  '1860 Lawrence Ave E',
#  '1955 Steeles Ave E',
#  '5351 Yonge St',
#  '1 Overland Dr',
#  '795 Eglinton Ave E',
#  '685 Finch Ave W',
#  '1145 Albion Rd',
#  '30 Bond St',
#  '140 Sherway Dr',
#  '200 Dawes Rd',
#  '4180 Dundas St W',
#  '17 Maplewood Ave',
#  '4001 Leslie St',
#  '645 Castlefield Ave',
#  '880 Lawrence Ave E',
#  '25 Centennial Park Rd',
#  '148 Markham Rd',
#  '3560 Bathurst St',
#  '2030 McNicoll Ave',
#  '205 Cummer Ave',
#  '285 Cummer Ave',
#  '200 Elizabeth St',
#  '102 Craiglee Dr',
#  '4251 Dundas St W',
#  '600 Melita Cres',
#  '866 Sheppard Ave W',
#  '92 Island Rd',
#  '351 Christie St',
#  '45 Brunswick Ave',
#  '2233 Kipling Ave',
#  '420 The East Mall',
#  '33 Christie St',
#  '450 Rustic Rd',
#  '95 Humber College Blvd',
#  '4005 Eglinton Ave W - 2nd, 7th, 8th & 9th Fl',
#  '40 Old Kingston Rd',
#  '77 Main St',
#  '47 Austin Terr',
#  '2701 St Clair Ave E',
#  '1001 Queen St W - Unit 2-2',
#  '439 Sherbourne St',
#  '1925 Steeles Ave E',
#  '345 Sherbourne St',
#  '1 Canterbury Pl',
#  '2601 Bayview Ave',
#  '10 Senlac Rd',
#  "1800 O'Connor Dr",
#  '3830 Lawrence Ave E',
#  '550 Cummer Ave',
#  '555 University Ave',
#  '2245 Lawrence Ave W',
#  '420 East Mall',
#  '500 Kingston Rd',
#  '111 Avenue Rd',
#  '60 Scottfield Dr',
#  '2411 Lawrence Ave E',
#  '70 Humberline Dr',
#  '35 Elm Grove Ave',
#  '600 University Ave',
#  '2867 Ellesmere Rd',
#  '40 Playfair Ave',
#  '9 Neilson Rd',
#  '3015 Lawrence Ave E',
#  '5 Resurrection Rd',
#  '400 The West Mall',
#  '520 Markham Rd',
#  '155 Balmoral Ave',
#  '65 Livingston Rd',
#  '22 Norfinch Dr',
#  "36 D'Arcy St",
#  '3050 Lawrence Ave E',
#  '9 Huntley St',
#  '303 Finch Ave E',
#  '55 Belmont St',
#  '339 George St',
#  '1020 McNicoll Ave',
#  '225 St George St',
#  '1140 Bloor St W',
#  '84 Davisville Ave',
#  '340 McCowan Rd',
#  '1400 Kennedy Rd',
#  '59 Lawson Rd',
#  '2121 Kingston Rd',
#  '720 Mount Pleasant Rd',
#  '399 Bathurst St',
#  '54 Foxbar Rd',
#  '3276 St Clair Ave E - 2 West (Elm & Pine)',
#  '420 The West Mall',
#  '150 Kilgour Rd',
#  '221 Milner Ave',
#  '82 Buttonwood Ave - (Kingsway/Ilaaci unit)',
#  '2045 Finch Ave W',
#  '4 Teddington Park Ave',
#  '130 Dunn Ave',
#  '625 Runnymede Rd',
#  '550 University Ave',
#  '9 Nielson Rd',
#  '47 Austin Terrace',
#  '160 Wellesley St E',
#  '215 Tyrrel Ave',
#  '541 Finch Ave W',
#  '155 Millwood Rd -  (Lawrence & Fisher unit)',
#  '3197 Lakeshore Blvd W',
#  '14 Cross St',
#  '101 Humber College Blvd',
#  '1001 Queen St W - Unit 1-2',
#  '10 William Morgan Dr',
#  '2339 Dufferin St',
#  '1001 Queen St W - Unit 1-3 LGUB',
#  '1066 Avenue Rd',
#  '60 Richview Rd',
#  '1000 Ellesmere Rd',
#  '60 Guildwood Pky',
#  '1001 Queen St W - 80 Workman Way - 3rd Fl',
#  '250 College St',
#  '60 Scottfield Dr - 4th Fl',
#  '2239 Dufferin St',
#  '1 Northwestern Ave',
#  '914 Bathurst St',
#  '147 Elder St',
#  '60 Scottfield Dr - 2nd Fl',
#  '1001 Queen St W',
#  '3276 St Clair Ave E - Balsam & Maple',
#  '5935 Bathurst St',
#  '1001 Queen St W - 80 Workman Way - 2nd Fl GAU-A',
#  '2311 McNicoll Ave',
#  '2005 Lawrence Ave W - 1st Fl',
#  '14 St Matthews Rd',
#  '3760 Sheppard Ave E',
#  '66 Roncesvalles Ave',
#  '122 Tyndall Ave',
#  '305 Balliol St',
#  '3050 Lawrence Ave E - CP1',
#  '1340 York Mills Rd',
#  '3595 Keele St',
#  '306 Finch Ave E',
#  '52 Neilson Dr',
#  '2030 Mcnicoll Ave',
#  '767 Royal York Rd',
#  '150 Dunn Ave',
#  '1001 Queen St W - Unit 2-4',
#  '25 Brunswick Ave',
#  '123 Spadina Rd',
#  '15 Barbery Pl',
#  '60 Scottfield Dr - 3rd & 5th Fl',
#  '8 Donway Pl E',
#  '550 University Ave - 6 South',
#  '3705 Bathurst St',
#  '1238 Queen St E',
#  '2005 Lawrence Ave W',
#  '610 University Ave',
#  '718 Sheppard Ave W',
#  '5758 Sheppard Ave E',
#  '43 Wellesley St E - 17E Holland Centre',
#  '4005 Eglinton Ave W',
#  '3838 Bloor St W',
#  '3015 Lawrence Ave E - 1st & 2nd Fl',
#  '215 Tyrrell Ave',
#  '3555 Kingston Rd',
#  '2339 Dufferin St - TCP & RIU',
#  '260 Bayview Ave',
#  '2881 Eglinton Ave E',
#  '262 St Clair Ave E',
#  '2100 Bloor St W',
#  '3276 St Clair Ave E - F3 East',
#  '3030 Birchmount Rd',
#  '740 Pape Ave',
#  '610 Universtiy Ave',
#  '303 Queens Dr',
#  '8 The Donway E',
#  '505 Kingston Rd',
#  '15 Barberry Pl',
#  '10/14 William Morgan Dr',
#  '138 Dowling Ave',
#  '8 Donway Pl',
#  '28 Halton St',
#  '650 Church St',
#  '187 Wynford Dr',
#  '43 Wellesley St E',
#  '700 & 720 Mount Pleasant Rd',
#  '8 Bridlington St',
#  '3276 St Clair Ave E - & West',
#  '55 Belmont',
#  '600 University Ave - 12 South & EXAU',
#  '60 Scottfield Dr - 6th Fl',
#  '215 Tyrell Ave',
#  '2111 Finch Ave W',
#  '550 University Ave - University Centre - 6 South',
#  '2111 Finch Ave W - 6 West',
#  '250 College St - EPU 10th Fl',
#  '700 & 720 Mount Pleasant Rd - 6th, 7th, 8th & 9th Fl',
#  '150 Sherway Dr - Complex Care Unit',
#  '3276 St Clair Ave E - Juniper House',
#  '3197 Lake Shore Blvd W',
#  '1001 Queen St W - Unit 1-3',
#  '140 Sherway Dr - 2nd & 4th Fl',
#  '650 Church St - 5th Fl',
#  '921 Millwood Rd',
#  '300 Silver Star Blvd',
#  '71 Humberline Dr',
#  '3276 St Clair Ave E - 2nd Fl East (Spruce/Chestnut)',
#  '200 Church St',
#  '877 Yonge St',
#  '2100 Bloor St W - 2nd & 3rd Fl - Tower A',
#  '1 Kenton Dr',
#  '211 Finch Ave W',
#  '150 Kilgour Rd - BIRT Wing 3rd Fl',
#  '15 Summerland Terr',
#  '1001 Queen St W -  GAU A & B, 2nd & 3rd Fl',
#  '2111 Finch Ave W - Southlake Regional Health Centre - 5 East',
#  '3278 St Clair Ave E',
#  '82 Buttonwood Ave - 2nd Fl (Hughes/Pritti), 3rd Fl (Glenwyld',
#  '155 Millwood Rd',
#  '35 Elm Grove Rd',
#  '3760 Sheppard Ave',
#  '14 William Morgan Dr',
#  '130 Dunn Ave - South 3, 4 & 5',
#  '3197 Lakeshore Blvd',
#  '130 Dunn Avenue',
#  '14 Cross Street',
#  '1400 Kennedy Road',
#  '30 Bond Street',
#  '60 Guildwood Parkway',
#  '10 Senlac Road',
#  '200 Elizabeth Street',
#  '35 Elm Grove Avenue',
#  '2100 Bloor Street - & 5th Fl Assisted Living',
#  '2920 Lawrence Avenue East',
#  '200 Church Street',
#  '215 Tyrrel Avenue',
#  '1925 Steeles Avenue East',
#  '40 Old Kingston Road',
#  '520 Markham Road',
#  '25 Brunswick Avenue',
#  '550 Cummer Avenue',
#  "1800 O'Connor Drive",
#  '150 Dunn Avenue',
#  '914 Bathurst Street',
#  '3030 Birchmount Rd.',
#  '2075 Bayview Avenue',
#  '82 Buttonwood Avenue',
#  '28 Halton Street',
#  '101 Humber College Boulevard',
#  '3560 Bathurst Street',
#  '1-3 Kenton Road',
#  '265 Queens Dr',
#  '55 Ameer Avenue',
#  '2 Buchan Court - 2nd, 3rd & 4th Fl',
#  '200 Elizabeth Street - Cath Lab',
#  '825 Coxwell Avenue - CIU-A',
#  '285 Cummer Ave - A2',
#  '10-14 William Morgan Drive',
#  '3758 Sheppard Ave E',
#  '2121 Kingston Road',
#  '1020 McNicoll Avenue',
#  '60 Scottfield Drive',
#  '8 The Donway   E',
#  '4650 Eglinton Ave W',
#  '600 University Avenue',
#  '429 Walmer Rd E',
#  '30  The Queensway',
#  '124 Dowling Ave',
#  '15 Barberry Place',
#  '1001 Queen Street West',
#  '55 Ameer Ave',
#  "2245 Lawrence Ave W - & Becker's Unit",
#  '340 McCowan Rd E',
#  '8 Snowy Owl Way',
#  '1235 Wilson Ave',
#  '200 Dawes Rd E',
#  '3595 Keele St - East Unit',
#  '250 College St - GPU-A',
#  '3276 St. Clair Ave E',
#  '4 Teddington Ave',
#  '225 St.George St',
#  '2245 Lawrence Ave W - Weston & Islington',
#  '40 Bell Estates Rd',
#  '77 Dunfield Ave',
#  '475 Rustic Rd',
#  '3030 Birchmount Rd - 4A Medicine',
#  '25 Bruinswick Ave',
#  '550 University Ave - 7 South',
#  '2100 Bloor St W - C, D',
#  '22 Norfinch Ave',
#  '5395 Bathurst St',
#  '1035 Eglinton Ave W',
#  '8 The Don Way E',
#  '285 Cummer Ave E',
#  '61 Fairfax Cres',
#  '10/14 Willian Morgan Dr',
#  '1 Sand Beach Rd',
#  '101 Humber College Blvd - 7 East',
#  '340 McCowen Rd - & 7th Fl',
#  '720 Mount Pleasant Rd - 12th Fl',
#  '129 Spadina Rd',
#  '2100 Bloor St W - Section - 4 Fls',
#  '10 William Morgan Dr - Bldg 10',
#  '2111 Finch Ave - 5 East',
#  '262 St. Clair Ave W',
#  '537 Finch Ave W',
#  "22 O'Connor Dr",
#  '54 Foxbar Ave',
#  '8 Ressurection Rd',
#  '80 Workman Way',
#  '140 Sherway Ave',
#  '82 Buttonwood Ave - 2EC',
#  '14 Willaim Morgan Dr',
#  '2701 St. Clair Ave E',
#  '3555 Danforth Ave - &  2 West (Topaz)',
#  '1001 Queen St W -  Unit 1-5 LGUD',
#  '200 Church St - C2N',
#  '66 Guildwood Ave',
#  '886 Sheppard Ave E',
#  '520 Sutherland Dr',
#  '4001 Leslie Street',
#  '180 Sheridan Ave - 3rd, 5th, 6th & 7th Fl',
#  '65 Livingston Rd - (Memory unit)',
#  '10 -14 William Morgan Drive',
#  '15 Summerland Terr - Concierge/Front Desk',
#  '2311 McNicoll Ave - & 5 Fl',
#  '52 Neilson Dr - Laundry & Kitchen',
#  '3030 Lawrence Ave E - Palliative Care/Oncology',
#  '3030 Lawrence Ave. E.',
#  '2075 Bayview Ave - LSSE',
#  '25 Brunswick Ave - 4W',
#  '2075 Bayview Ave - LTSE',
#  '155 Millwood Rd - 4N',
#  '2701 St Clair Avenue East',
#  '1235 Wilson Avenue',
#  '14 St. Matthews Road',
#  '200 Elizabeth Street - In-Centre Hemodialysis',
#  '2100 Bloor St W - & Main Kitchen',
#  '66 Roncesvalles Ave - Admin Area & Kitchen',
#  '400 The West Mall - Main Fl & Laundry',
#  '200 Elizabeth St - ENT Laryngology - Administrative Offices',
#  '2245 Lawrence Ave W - Islington, Brule & Wadsworth',
#  '225 St. George St',
#  '2245 Lawrence Ave W - Emma & WIlliamsburg East',
#  '262 St. Clair Avenue W',
#  '700 Mount Pleasant Rd',
#  '38 Major St',
#  '707 Ellesmere Rd',
#  '600 Melita Crescent',
#  '5 Resurrection Road',
#  '3030 Lawrence Ave E',
#  '625 Runnymede Road',
#  '3030 Lawrence Ave E - Medicine Unit',
#  '399 Bathurst Street',
#  '2867 Ellesmere Road',
#  '555 University Avenue',
#  '22 Norfinch Drive',
#  '200 Elizabeth Street - Transportation & Linen Services',
#  '340 McCowan Road',
#  '200 Elizabeth Street - 5B Cardiology',
#  '520 Sutherland Drive',
#  '500 Kingston Rd.',
#  '4251 Dundas Street St W',
#  '66 Roncesvalles Avenue',
#  '285 Cummer Avenue',
#  '3276 St. Clair Avenue East',
#  '225 St. George Street',
#  '4180 Dundas Street',
#  '70 Humberline Drive',
#  '101 Humber College Boulevard - 7E Cardiology',
#  '2045 Finch Ave West',
#  '205 Cummer Avenue',
#  '685 Finch Ave West',
#  '200 Elizabeth Street - Hemodialysis Centre',
#  '2005 Lawrence Avenue West',
#  '52 Neilson Drive',
#  '825 Coxwell Avenue',
#  '3830 Lawrence Avenue East',
#  '101 Humber College Boulevard - 8 Medflex',
#  '1195 Queen Street East',
#  "2 O'Connor Dr",
#  '866 Sheppard Avenue',
#  '160 Wellesley Street East',
#  '399 Bathurst St - 6B',
#  '200 Elizabeth Street - OR Staff areas',
#  '200 Elizabeth Street - Hemodialysis Unit',
#  '1000 Ellesmere Road',
#  '399 Bathrust Street',
#  '77 Main Street',
#  '2339 Dufferin Street',
#  '303 Queens Drive',
#  '825 Coxwell Avenue - palliative care',
#  '306 Finch Avenue East',
#  '45 Brunswick Avenue',
#  '1066 Avenue Road',
#  '200 Elizabeth Street - EVS',
#  '2111 Finch Avenue West',
#  '4005 Eglinton Avenue',
#  '40 Bell Estate Road',
#  '2030 McNicoll Avenue',
#  '102 Craiglee Drive',
#  '77 Dunfield Avenue',
#  '148 Markham Road',
#  '740 Pape Avenue',
#  '500 Kingston Road - 3rd Fl',
#  '429 Walmer Road',
#  '5935 Bathurst Street',
#  '205 Cummer',
#  '500 Kingston Road',
#  '33 Christie Street',
#  '59 Lawson Road',
#  '4180 Dundas Street W',
#  '60 Richview Road',
#  '1035 Eglinton Avenue W',
#  '1029 McNicoll Ave',
#  '3760 Sheppard Avenue East',
#  '146 Sumach St',
#  '4005 Eglinton Avenue W',
#  '685 Finch Avenue',
#  '1-3 Kenton Dr',
#  '1 Northwestern Avenue',
#  '10-14 William Morgan Dr',
#  '3758 Sheppard Avenue E',
#  '537 Finch Avenue',
#  '180 Sheridan Ave',
#  '19 Reans Dr',
#  '4251 Dundas Street W',
#  '147 Elder Street',
#  '4650 Eglinton Avenue West',
#  '2881 Eglinton Avenue E',
#  '610 University Avenue',
#  '880 Lawrence Avenue',
#  '921 Millwood Road',
#  '4 Teddington Park Avenue',
#  '140 Sherway Drive',
#  '1055-1057 Don Mills Rd',
#  '1238 Queen Street',
#  '2245 Lawrence Avenue West',
#  '155 Dunn Ave',
#  '59 Lawson Rd E',
#  '700 & 720 Mount Pleasant Road',
#  '4 Partridge Lane',
#  '718 Sheppard Avenue',
#  '550 University Avenue',
#  '705 - 707 Ellesmere Road',
#  '300 Silver Star Boulevard',
#  '2100 Bloor Street W',
#  '795 Eglinton Avenue E',
#  '43 Wellesley Street East',
#  '555 University Ave E',
#  '70 Humberline Dr W',
#  "36 D'arcy St",
#  '55 Belmont Street',
#  '92 Island Rd E',
#  '10 Fairfield Ave',
#  '155 Millwood Road',
#  '1001 Queen Street West - Unit 1-2',
#  '1001 Queen Street West - Unit 1-4',
#  '340 McCowan Rd - 3rd & 4th Fl',
#  '1001 Queen Street West - Unit 1-5',
#  '2075 Bayview Avenue - Unit PICU',
#  '111 Avenue Rd - Lower Lobby Staff Break Rm',
#  '28 Halton St.',
#  '1001 Queen Street West - Unit PRT7',
#  '2 Buchan Crt - 4th Fl',
#  '2075 Bayview Avenue - K1C & K1E',
#  '2867 Ellesmere Road - Complex Continuing Care',
#  '2867 Ellesmere Road -General Medicine Unit',
#  '345 Sherbourne St - Management Office & Craft Rm',
#  '650 Dixon Rd - Specialized Care Centre',
#  '2075 Bayview Ave - LFSE',
#  '2867 Ellesmere Road - 10W (Mental Health Unit)',
#  '200 Dawes Rd - Basement/Kitchen',
#  '3030 Birchmount Rd - G3C- Mental Health',
#  '3030 Lawrence Ave. E. - 2C-Nephorology',
#  '3030 Lawrence Ave. E.- T 9-Medicine',
#  '3030 Lawrence Ave. E. - 4E Medicine',
#  '1001 Queen Street West - Unit 1-3',
#  '1001 Queen Street West - Unit 3-1',
#  '33 Hahn Pl',
#  '30 The Queensway - Dialysis Unit - Main & Satellite Site',
#  '602 Brimley Rd',
#  '30 Bond Street - In-Centre Dialysis Unit',
#  '150 Sherway Dr - CCC Unit',
#  '76 Silversted Dr',
#  '2075 Bayview Ave - LFSW',
#  '1001 Queen Street West - Unit 3-5',
#  '3030 Lawrence Ave. E. - CP3 Surgery',
#  '3030 Lawrence Ave. E. - T7 Medicine',
#  '2075 Bayview Ave - LGSE',
#  '1001 Queen Street West - Unit 3-2',
#  '3030 Lawrence Ave. E. - T2 Nephrology',
#  '2075 Bayview Ave - LGSW',
#  '3030 Lawrence Ave. E - 3C - General Surgery',
#  '3276 St. Clair Ave East',
#  '1001 Queen St West',
#  "1800 O'Connor",
#  '2109 Finch Ave W',
#  '866 Sheppard Ave',
#  '1238 Queen St',
#  '3760 Sheppard Ave East',
#  '4650 Eglinton Ave West',
#  '122 Tyndale St',
#  '60 Guildowood Pky',
#  '2245 Lawrence Ave West',
#  '718 Sheppard Ave',
#  '262 St Clair Ave W',
#  '111 Ave Rd',
#  '52 McMurrich St',
#  '1001 Queen Ave W',
#  '1860 Lawrence Ave',
#  '2 Green Belt Dr',
#  '2701 St Clair Ave East',
#  '1020 Mcnicoll Ave',
#  '66 Roncesvales Ave',
#  '150 Sherway Drive',
#  '140 Humberline Dr',
#  '3050 Lawerence Ave E',
#  '3593 Keele St',
#  '1925 Steeles Ave',
#  '541 Finch Ave',
#  '555 Finch Avenue West']

# %%
#Manually clean up format of addresses stored in a new list
cleaned_addresses = ['551 Conlins Rd',
 '825 Coxwell Ave',
 '2920 Lawrence Ave E',
 '3555 Danforth Ave',
 '19 Rean Dr',
 '67 Belgreen Ave',
 '2 Buchan Crt',
 '429 Walmer Rd',
 '1 Bridgepoint Dr',
 '3276 St Clair Ave E',
 '82 Buttonwood Ave',
 '2075 Bayview Ave',
 '495 The West Mall',
 '40 Bell Estate Rd',
 '130 Midland Ave',
 '30 The Queensway',
 '1195 Queen St E',
 '1860 Lawrence Ave E',
 '1955 Steeles Ave E',
 '5351 Yonge St',
 '1 Overland Dr',
 '795 Eglinton Ave E',
 '685 Finch Ave W',
 '1145 Albion Rd',
 '30 Bond St',
 '140 Sherway Dr',
 '200 Dawes Rd',
 '4180 Dundas St W',
 '17 Maplewood Ave',
 '4001 Leslie St',
 '645 Castlefield Ave',
 '880 Lawrence Ave E',
 '25 Centennial Park Rd',
 '148 Markham Rd',
 '3560 Bathurst St',
 '2030 McNicoll Ave',
 '205 Cummer Ave',
 '285 Cummer Ave',
 '200 Elizabeth St',
 '102 Craiglee Dr',
 '4251 Dundas St W',
 '600 Melita Cres',
 '866 Sheppard Ave W',
 '92 Island Rd',
 '351 Christie St',
 '45 Brunswick Ave',
 '2233 Kipling Ave',
 '420 The East Mall',
 '33 Christie St',
 '450 Rustic Rd',
 '95 Humber College Blvd',
 '4005 Eglinton Ave W',
 '40 Old Kingston Rd',
 '77 Main St',
 '47 Austin Terr',
 '2701 St Clair Ave E',
 '1001 Queen St W',
 '439 Sherbourne St',
 '1925 Steeles Ave E',
 '345 Sherbourne St',
 '1 Canterbury Pl',
 '2601 Bayview Ave',
 '10 Senlac Rd',
 "1800 O'Connor Dr",
 '3830 Lawrence Ave E',
 '550 Cummer Ave',
 '555 University Ave',
 '2245 Lawrence Ave W',
 '420 East Mall',
 '500 Kingston Rd',
 '111 Avenue Rd',
 '60 Scottfield Dr',
 '2411 Lawrence Ave E',
 '70 Humberline Dr',
 '35 Elm Grove Ave',
 '600 University Ave',
 '2867 Ellesmere Rd',
 '40 Playfair Ave',
 '9 Neilson Rd',
 '3015 Lawrence Ave E',
 '5 Resurrection Rd',
 '400 The West Mall',
 '520 Markham Rd',
 '155 Balmoral Ave',
 '65 Livingston Rd',
 '22 Norfinch Dr',
 "36 D'Arcy St",
 '3050 Lawrence Ave E',
 '9 Huntley St',
 '303 Finch Ave E',
 '55 Belmont St',
 '339 George St',
 '1020 McNicoll Ave',
 '225 St George St',
 '1140 Bloor St W',
 '84 Davisville Ave',
 '340 McCowan Rd',
 '1400 Kennedy Rd',
 '59 Lawson Rd',
 '2121 Kingston Rd',
 '720 Mount Pleasant Rd',
 '399 Bathurst St',
 '54 Foxbar Rd',
 '3276 St Clair Ave E',
 '420 The West Mall',
 '150 Kilgour Rd',
 '221 Milner Ave',
 '82 Buttonwood Ave',
 '2045 Finch Ave W',
 '4 Teddington Park Ave',
 '130 Dunn Ave',
 '625 Runnymede Rd',
 '550 University Ave',
 '9 Nielson Rd',
 '47 Austin Terrace',
 '160 Wellesley St E',
 '215 Tyrrel Ave',
 '541 Finch Ave W',
 '155 Millwood Rd',
 '3197 Lakeshore Blvd W',
 '14 Cross St',
 '101 Humber College Blvd',
 '1001 Queen St W',
 '10 William Morgan Dr',
 '2339 Dufferin St',
 '1001 Queen St W',
 '1066 Avenue Rd',
 '60 Richview Rd',
 '1000 Ellesmere Rd',
 '60 Guildwood Pky',
 '1001 Queen St W',
 '250 College St',
 '60 Scottfield Dr',
 '2239 Dufferin St',
 '1 Northwestern Ave',
 '914 Bathurst St',
 '147 Elder St',
 '60 Scottfield Dr',
 '1001 Queen St W',
 '3276 St Clair Ave E',
 '5935 Bathurst St',
 '1001 Queen St W',
 '2311 McNicoll Ave',
 '2005 Lawrence Ave W',
 '14 St Matthews Rd',
 '3760 Sheppard Ave E',
 '66 Roncesvalles Ave',
 '122 Tyndall Ave',
 '305 Balliol St',
 '3050 Lawrence Ave E',
 '1340 York Mills Rd',
 '3595 Keele St',
 '306 Finch Ave E',
 '52 Neilson Dr',
 '2030 Mcnicoll Ave',
 '767 Royal York Rd',
 '150 Dunn Ave',
 '1001 Queen St W',
 '25 Brunswick Ave',
 '123 Spadina Rd',
 '15 Barbery Pl',
 '60 Scottfield Dr',
 '8 Donway Pl E',
 '550 University Ave',
 '3705 Bathurst St',
 '1238 Queen St E',
 '2005 Lawrence Ave W',
 '610 University Ave',
 '718 Sheppard Ave W',
 '5758 Sheppard Ave E',
 '43 Wellesley St E',
 '4005 Eglinton Ave W',
 '3838 Bloor St W',
 '3015 Lawrence Ave E',
 '215 Tyrrell Ave',
 '3555 Kingston Rd',
 '2339 Dufferin St',
 '260 Bayview Ave',
 '2881 Eglinton Ave E',
 '262 St Clair Ave E',
 '2100 Bloor St W',
 '3276 St Clair Ave E',
 '3030 Birchmount Rd',
 '740 Pape Ave',
 '610 Universtiy Ave',
 '303 Queens Dr',
 '8 The Donway E',
 '505 Kingston Rd',
 '15 Barberry Pl',
 '10/14 William Morgan Dr',
 '138 Dowling Ave',
 '8 Donway Pl',
 '28 Halton St',
 '650 Church St',
 '187 Wynford Dr',
 '43 Wellesley St E',
 '700 & 720 Mount Pleasant Rd',
 '8 Bridlington St',
 '3276 St Clair Ave E',
 '55 Belmont',
 '600 University Ave',
 '60 Scottfield Dr - 6th Fl',
 '215 Tyrell Ave',
 '2111 Finch Ave W',
 '550 University Ave',
 '2111 Finch Ave W',
 '250 College St',
 '700 & 720 Mount Pleasant Rd',
 '150 Sherway Dr',
 '3276 St Clair Ave E',
 '3197 Lake Shore Blvd W',
 '1001 Queen St W',
 '140 Sherway Dr',
 '650 Church St',
 '921 Millwood Rd',
 '300 Silver Star Blvd',
 '71 Humberline Dr',
 '3276 St Clair Ave E',
 '200 Church St',
 '877 Yonge St',
 '2100 Bloor St W',
 '1 Kenton Dr',
 '2111 Finch Ave W',
 '150 Kilgour Rd',
 '15 Summerland Terr',
 '1001 Queen St W',
 '2111 Finch Ave W',
 '3278 St Clair Ave E',
 '82 Buttonwood Ave',
 '155 Millwood Rd',
 '35 Elm Grove Rd',
 '3760 Sheppard Ave',
 '14 William Morgan Dr',
 '130 Dunn Ave',
 '3197 Lakeshore Blvd',
 '130 Dunn Avenue',
 '14 Cross Street',
 '1400 Kennedy Road',
 '30 Bond Street',
 '60 Guildwood Parkway',
 '10 Senlac Road',
 '200 Elizabeth Street',
 '35 Elm Grove Avenue',
 '2100 Bloor Street',
 '2920 Lawrence Avenue East',
 '200 Church Street',
 '215 Tyrrel Avenue',
 '1925 Steeles Avenue East',
 '40 Old Kingston Road',
 '520 Markham Road',
 '25 Brunswick Avenue',
 '550 Cummer Avenue',
 "1800 O'Connor Drive",
 '150 Dunn Avenue',
 '914 Bathurst Street',
 '3030 Birchmount Rd.',
 '2075 Bayview Avenue',
 '82 Buttonwood Avenue',
 '28 Halton Street',
 '101 Humber College Boulevard',
 '3560 Bathurst Street',
 '1-3 Kenton Road',
 '265 Queens Dr',
 '55 Ameer Avenue',
 '2 Buchan Court',
 '200 Elizabeth Street',
 '825 Coxwell Avenue',
 '285 Cummer Ave',
 '10-14 William Morgan Drive',
 '3758 Sheppard Ave E',
 '2121 Kingston Road',
 '1020 McNicoll Avenue',
 '60 Scottfield Drive',
 '8 The Donway E',
 '4650 Eglinton Ave W',
 '600 University Avenue',
 '429 Walmer Rd E',
 '30  The Queensway',
 '124 Dowling Ave',
 '15 Barberry Place',
 '1001 Queen Street West',
 '55 Ameer Ave',
 "2245 Lawrence Ave W",
 '340 McCowan Rd E',
 '8 Snowy Owl Way',
 '1235 Wilson Ave',
 '200 Dawes Rd E',
 '3595 Keele St',
 '250 College St',
 '3276 St. Clair Ave E',
 '4 Teddington Ave',
 '225 St.George St',
 '2245 Lawrence Ave W',
 '40 Bell Estates Rd',
 '77 Dunfield Ave',
 '475 Rustic Rd',
 '3030 Birchmount Rd',
 '25 Bruinswick Ave',
 '550 University Ave',
 '2100 Bloor St W',
 '22 Norfinch Ave',
 '5395 Bathurst St',
 '1035 Eglinton Ave W',
 '8 The Don Way E',
 '285 Cummer Ave E',
 '61 Fairfax Cres',
 '10/14 Willian Morgan Dr',
 '1 Sand Beach Rd',
 '101 Humber College Blvd',
 '340 McCowen Rd',
 '720 Mount Pleasant Rd',
 '129 Spadina Rd',
 '2100 Bloor St W',
 '10 William Morgan Dr',
 '2111 Finch Ave',
 '262 St. Clair Ave W',
 '537 Finch Ave W',
 "22 O'Connor Dr",
 '54 Foxbar Ave',
 '8 Ressurection Rd',
 '80 Workman Way',
 '140 Sherway Ave',
 '82 Buttonwood Ave',
 '14 Willaim Morgan Dr',
 '2701 St. Clair Ave E',
 '3555 Danforth Ave',
 '1001 Queen St W',
 '200 Church St',
 '66 Guildwood Ave',
 '886 Sheppard Ave E',
 '520 Sutherland Dr',
 '4001 Leslie Street',
 '180 Sheridan Ave',
 '65 Livingston Rd',
 '10-14 William Morgan Drive',
 '15 Summerland Terr',
 '2311 McNicoll Ave',
 '52 Neilson Dr',
 '3030 Lawrence Ave E',
 '3030 Lawrence Ave. E.',
 '2075 Bayview Ave',
 '25 Brunswick Ave',
 '2075 Bayview Ave',
 '155 Millwood Rd',
 '2701 St Clair Avenue East',
 '1235 Wilson Avenue',
 '14 St. Matthews Road',
 '200 Elizabeth Street',
 '2100 Bloor St W ',
 '66 Roncesvalles Ave',
 '400 The West Mall',
 '200 Elizabeth St',
 '2245 Lawrence Ave W',
 '225 St. George St',
 '2245 Lawrence Ave W',
 '262 St. Clair Avenue W',
 '700 Mount Pleasant Rd',
 '38 Major St',
 '707 Ellesmere Rd',
 '600 Melita Crescent',
 '5 Resurrection Road',
 '3030 Lawrence Ave E',
 '625 Runnymede Road',
 '3030 Lawrence Ave E',
 '399 Bathurst Street',
 '2867 Ellesmere Road',
 '555 University Avenue',
 '22 Norfinch Drive',
 '200 Elizabeth Street',
 '340 McCowan Road',
 '200 Elizabeth Street',
 '520 Sutherland Drive',
 '500 Kingston Rd.',
 '4251 Dundas Street St W',
 '66 Roncesvalles Avenue',
 '285 Cummer Avenue',
 '3276 St. Clair Avenue East',
 '225 St. George Street',
 '4180 Dundas Street',
 '70 Humberline Drive',
 '101 Humber College Boulevard',
 '2045 Finch Ave West',
 '205 Cummer Avenue',
 '685 Finch Ave West',
 '200 Elizabeth Street',
 '2005 Lawrence Avenue West',
 '52 Neilson Drive',
 '825 Coxwell Avenue',
 '3830 Lawrence Avenue East',
 '101 Humber College Boulevard',
 '1195 Queen Street East',
 "2 O'Connor Dr",
 '866 Sheppard Avenue',
 '160 Wellesley Street East',
 '399 Bathurst St - 6B',
 '200 Elizabeth Street',
 '200 Elizabeth Street',
 '1000 Ellesmere Road',
 '399 Bathrust Street',
 '77 Main Street',
 '2339 Dufferin Street',
 '303 Queens Drive',
 '825 Coxwell Avenue',
 '306 Finch Avenue East',
 '45 Brunswick Avenue',
 '1066 Avenue Road',
 '200 Elizabeth Street',
 '2111 Finch Avenue West',
 '4005 Eglinton Avenue',
 '40 Bell Estate Road',
 '2030 McNicoll Avenue',
 '102 Craiglee Drive',
 '77 Dunfield Avenue',
 '148 Markham Road',
 '740 Pape Avenue',
 '500 Kingston Road',
 '429 Walmer Road',
 '5935 Bathurst Street',
 '205 Cummer',
 '500 Kingston Road',
 '33 Christie Street',
 '59 Lawson Road',
 '4180 Dundas Street W',
 '60 Richview Road',
 '1035 Eglinton Avenue W',
 '1029 McNicoll Ave',
 '3760 Sheppard Avenue East',
 '146 Sumach St',
 '4005 Eglinton Avenue W',
 '685 Finch Avenue',
 '1-3 Kenton Dr',
 '1 Northwestern Avenue',
 '10-14 William Morgan Dr',
 '3758 Sheppard Avenue E',
 '537 Finch Avenue',
 '180 Sheridan Ave',
 '19 Reans Dr',
 '4251 Dundas Street W',
 '147 Elder Street',
 '4650 Eglinton Avenue West',
 '2881 Eglinton Avenue E',
 '610 University Avenue',
 '880 Lawrence Avenue',
 '921 Millwood Road',
 '4 Teddington Park Avenue',
 '140 Sherway Drive',
 '1055-1057 Don Mills Rd',
 '1238 Queen Street',
 '2245 Lawrence Avenue West',
 '155 Dunn Ave',
 '59 Lawson Rd E',
 '700 & 720 Mount Pleasant Road',
 '4 Partridge Lane',
 '718 Sheppard Avenue',
 '550 University Avenue',
 '705 - 707 Ellesmere Road',
 '300 Silver Star Boulevard',
 '2100 Bloor Street W',
 '795 Eglinton Avenue E',
 '43 Wellesley Street East',
 '555 University Ave E',
 '70 Humberline Dr W',
 "36 D'arcy St",
 '55 Belmont Street',
 '92 Island Rd E',
 '10 Fairfield Ave',
 '155 Millwood Road',
 '1001 Queen Street West',
 '1001 Queen Street West',
 '340 McCowan Rd',
 '1001 Queen Street West',
 '2075 Bayview Avenue',
 '111 Avenue Rd',
 '28 Halton St.',
 '1001 Queen Street West',
 '2 Buchan Crt',
 '2075 Bayview Avenue',
 '2867 Ellesmere Road',
 '2867 Ellesmere Road',
 '345 Sherbourne St',
 '650 Dixon Rd',
 '2075 Bayview Ave',
 '2867 Ellesmere Road',
 '200 Dawes Rd',
 '3030 Birchmount Rd',
 '3030 Lawrence Ave. E.',
 '3030 Lawrence Ave. E.',
 '3030 Lawrence Ave. E.',
 '1001 Queen Street West',
 '1001 Queen Street West',
 '33 Hahn Pl',
 '30 The Queenswaye',
 '602 Brimley Rd',
 '30 Bond Streett',
 '150 Sherway Dr',
 '76 Silversted Dr',
 '2075 Bayview Ave',
 '1001 Queen Street West5',
 '3030 Lawrence Ave. E.y',
 '3030 Lawrence Ave. E.',
 '2075 Bayview Ave',
 '1001 Queen Street West',
 '3030 Lawrence Ave. E.',
 '2075 Bayview Ave',
 '3030 Lawrence Ave. E',
 '3276 St. Clair Ave East',
 '1001 Queen St West',
 "1800 O'Connor",
 '2109 Finch Ave W',
 '866 Sheppard Ave',
 '1238 Queen St',
 '3760 Sheppard Ave East',
 '4650 Eglinton Ave West',
 '122 Tyndale St',
 '60 Guildowood Pky',
 '2245 Lawrence Ave West',
 '718 Sheppard Ave',
 '262 St Clair Ave W',
 '111 Ave Rd',
 '52 McMurrich St',
 '1001 Queen Ave W',
 '1860 Lawrence Ave',
 '2 Green Belt Dr',
 '2701 St Clair Ave East',
 '1020 Mcnicoll Ave',
 '66 Roncesvales Ave',
 '150 Sherway Drive',
 '140 Humberline Dr',
 '3050 Lawerence Ave E',
 '3593 Keele St',
 '1925 Steeles Ave',
 '541 Finch Ave',
 '555 Finch Avenue West']

# %%
#Import dependencies for API
import requests
import json
from pprint import pprint

#Import API key from config file
from config import geoapify_key

# %%
#Use Geocoding API to get the place ID for Toronto, to be used in the Address Autocomplete API parameters
#Using the place ID in the Address API will limit the results to the city of Toronto
geo_url = f"https://api.geoapify.com/v1/geocode/search?city=Toronto&type=city&format=json&apiKey={geoapify_key}"
geo_response = requests.get(geo_url).json()
pprint(geo_response)
toronto_place_id = geo_response['results'][0]['place_id']
# Out:
# {'query': {'city': 'Toronto',
#            'parsed': {'city': 'Toronto', 'expected_type': 'unknown'},
#            'text': ''},
#  'results': [{'address_line1': 'Toronto, ON',
#               'address_line2': 'Canada',
#               'bbox': {'lat1': 43.5796082,
#                        'lat2': 43.8554414,
#                        'lon1': -79.6392832,
#                        'lon2': -79.1132193},
#               'category': 'administrative',
#               'city': 'Toronto',
#               'country': 'Canada',
#               'country_code': 'ca',
#               'county': 'Golden Horseshoe',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Toronto, ON, Canada',
#               'lat': 43.6534817,
#               'lon': -79.3839347,
#               'place_id': '512c13d96292d853c0596a04d149a5d34540f00101f90173f2040000000000c00208',
#               'plus_code': '87M2MJ38+9C',
#               'plus_code_short': 'MJ38+9C Toronto, Golden Horseshoe, Canada',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.8230149417022804,
#                        'match_type': 'match_by_city_or_disrict',
#                        'popularity': 8.474143437228948},
#               'result_type': 'city',
#               'state': 'Ontario',
#               'state_code': 'ON',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/Toronto',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}},
#              {'address_line1': 'Toronto, PE',
#               'address_line2': 'Canada',
#               'bbox': {'lat1': 46.4305437,
#                        'lat2': 46.4662257,
#                        'lon1': -63.3982902,
#                        'lon2': -63.3671092},
#               'category': 'administrative',
#               'city': 'Toronto',
#               'country': 'Canada',
#               'country_code': 'ca',
#               'county': 'Queens County',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Toronto, PE, Canada',
#               'lat': 46.4524682,
#               'lon': -63.3799629,
#               'place_id': '51bf98d29fa2b04fc05970bd5c7aea394740f00101f9014392b70000000000c00208',
#               'plus_code': '87RRFJ2C+X2',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.4600099999999999,
#                        'match_type': 'match_by_city_or_disrict',
#                        'popularity': 0.7751073925502354},
#               'result_type': 'city',
#               'state': 'Prince Edward Island',
#               'state_code': 'PE',
#               'timezone': {'abbreviation_DST': 'ADT',
#                            'abbreviation_STD': 'AST',
#                            'name': 'America/Halifax',
#                            'offset_DST': '-03:00',
#                            'offset_DST_seconds': -10800,
#                            'offset_STD': '-04:00',
#                            'offset_STD_seconds': -14400}},
#              {'address_line1': 'Toronto, IA',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 41.8987461,
#                        'lat2': 41.9065584,
#                        'lon1': -90.8672568,
#                        'lon2': -90.8594528},
#               'category': 'administrative',
#               'city': 'Toronto',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Clinton County',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Toronto, IA, United States of America',
#               'lat': 41.9048584,
#               'lon': -90.8640346,
#               'place_id': '513267c7574cb756c05965c16966d2f34440f00101f9019df5010000000000c00208',
#               'plus_code': '86HFW43P+W9',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.5453653500823205,
#                        'match_type': 'match_by_city_or_disrict',
#                        'popularity': 1.16436910661117},
#               'result_type': 'city',
#               'state': 'Iowa',
#               'state_code': 'IA',
#               'timezone': {'abbreviation_DST': 'CDT',
#                            'abbreviation_STD': 'CST',
#                            'name': 'America/Chicago',
#                            'offset_DST': '-05:00',
#                            'offset_DST_seconds': -18000,
#                            'offset_STD': '-06:00',
#                            'offset_STD_seconds': -21600}},
#              {'address_line1': 'Toronto, KS',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 37.792721,
#                        'lat2': 37.803752,
#                        'lon1': -95.956873,
#                        'lon2': -95.9412801},
#               'category': 'administrative',
#               'city': 'Toronto',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Woodson County',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Toronto, KS, United States of America',
#               'lat': 37.7989253,
#               'lon': -95.9491562,
#               'place_id': '51ec72a5f9befc57c05937b9292f43e64240f00101f9018dfa010000000000c00208',
#               'plus_code': '8696Q3X2+H8',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.5260865819376758,
#                        'match_type': 'match_by_city_or_disrict',
#                        'popularity': 1.5248364907590228},
#               'result_type': 'city',
#               'state': 'Kansas',
#               'state_code': 'KS',
#               'timezone': {'abbreviation_DST': 'CDT',
#                            'abbreviation_STD': 'CST',
#                            'name': 'America/Chicago',
#                            'offset_DST': '-05:00',
#                            'offset_DST_seconds': -18000,
#                            'offset_STD': '-06:00',
#                            'offset_STD_seconds': -21600}},
#              {'address_line1': 'Toronto, OH',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 40.436469,
#                        'lat2': 40.4832531,
#                        'lon1': -80.622815,
#                        'lon2': -80.5961972},
#               'category': 'administrative',
#               'city': 'Toronto',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Jefferson County',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Toronto, OH, United States of America',
#               'lat': 40.4653962,
#               'lon': -80.6009547,
#               'place_id': '5129b8b30a762654c0596257491a923b4440f00101f90192cc020000000000c00208',
#               'plus_code': '86GXF98X+5J',
#               'plus_code_short': '8X+5J Toronto, Jefferson County, United '
#                                  'States',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.45837647060696385,
#                        'match_type': 'match_by_city_or_disrict',
#                        'popularity': 2.1844249179519544},
#               'result_type': 'city',
#               'state': 'Ohio',
#               'state_code': 'OH',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/New_York',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}}]}

# %%
#Separate cleaned_addresses into 4 smaller lists
clean_add_1 = cleaned_addresses[0:133]
clean_add_2 = cleaned_addresses[133:266]
clean_add_3 = cleaned_addresses[266:399]
clean_add_4 = cleaned_addresses[399:534]

# %%
#API call for first list of addresses
clean_dict = {}
failed_addresses = []

for i in range(0, len(clean_add_1)):
    address = clean_add_1[i]
    address_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={address}&filter=place:{toronto_place_id}&format=json&apiKey={geoapify_key}"
    address_response = requests.get(address_url).json()
    try:
        latitude = address_response['results'][0]['lat']
        longitude = address_response['results'][0]['lon']
        coords = [longitude, latitude]
        clean_dict[address] = coords
        print(f'API call successful for index {i}')
    except IndexError:
        failed_addresses.append(address)
        print(f'API call failed for index {i}')
# Out:
# API call successful for index 0
# API call successful for index 1
# API call successful for index 2
# API call successful for index 3
# API call successful for index 4
# API call successful for index 5
# API call successful for index 6
# API call successful for index 7
# API call successful for index 8
# API call successful for index 9
# API call successful for index 10
# API call successful for index 11
# API call successful for index 12
# API call successful for index 13
# API call successful for index 14
# API call successful for index 15
# API call successful for index 16
# API call successful for index 17
# API call successful for index 18
# API call successful for index 19
# API call successful for index 20
# API call successful for index 21
# API call successful for index 22
# API call successful for index 23
# API call successful for index 24
# API call successful for index 25
# API call successful for index 26
# API call successful for index 27
# API call successful for index 28
# API call successful for index 29
# API call successful for index 30
# API call successful for index 31
# API call successful for index 32
# API call successful for index 33
# API call successful for index 34
# API call successful for index 35
# API call successful for index 36
# API call successful for index 37
# API call successful for index 38
# API call successful for index 39
# API call successful for index 40
# API call successful for index 41
# API call successful for index 42
# API call successful for index 43
# API call successful for index 44
# API call successful for index 45
# API call successful for index 46
# API call successful for index 47
# API call successful for index 48
# API call successful for index 49
# API call successful for index 50
# API call successful for index 51
# API call successful for index 52
# API call successful for index 53
# API call successful for index 54
# API call successful for index 55
# API call successful for index 56
# API call successful for index 57
# API call successful for index 58
# API call successful for index 59
# API call successful for index 60
# API call successful for index 61
# API call successful for index 62
# API call successful for index 63
# API call successful for index 64
# API call successful for index 65
# API call successful for index 66
# API call successful for index 67
# API call successful for index 68
# API call successful for index 69
# API call successful for index 70
# API call successful for index 71
# API call successful for index 72
# API call successful for index 73
# API call successful for index 74
# API call successful for index 75
# API call successful for index 76
# API call successful for index 77
# API call successful for index 78
# API call successful for index 79
# API call successful for index 80
# API call successful for index 81
# API call successful for index 82
# API call successful for index 83
# API call successful for index 84
# API call successful for index 85
# API call successful for index 86
# API call successful for index 87
# API call successful for index 88
# API call successful for index 89
# API call successful for index 90
# API call successful for index 91
# API call successful for index 92
# API call successful for index 93
# API call successful for index 94
# API call successful for index 95
# API call successful for index 96
# API call successful for index 97
# API call successful for index 98
# API call successful for index 99
# API call successful for index 100
# API call successful for index 101
# API call successful for index 102
# API call successful for index 103
# API call failed for index 104
# API call successful for index 105
# API call successful for index 106
# API call successful for index 107
# API call successful for index 108
# API call successful for index 109
# API call successful for index 110
# API call successful for index 111
# API call successful for index 112
# API call failed for index 113
# API call successful for index 114
# API call successful for index 115
# API call successful for index 116
# API call successful for index 117
# API call successful for index 118
# API call failed for index 119
# API call failed for index 120
# API call successful for index 121
# API call successful for index 122
# API call successful for index 123
# API call successful for index 124
# API call successful for index 125
# API call successful for index 126
# API call successful for index 127
# API call successful for index 128
# API call successful for index 129
# API call successful for index 130
# API call successful for index 131
# API call successful for index 132

# %%
#API call for second list of addresses

for i in range(0, len(clean_add_2)):
    address = clean_add_2[i]
    address_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={address}&filter=place:{toronto_place_id}&format=json&apiKey={geoapify_key}"
    address_response = requests.get(address_url).json()
    try:
        latitude = address_response['results'][0]['lat']
        longitude = address_response['results'][0]['lon']
        coords = [longitude, latitude]
        clean_dict[address] = coords
        print(f'API call successful for index {i}')
    except IndexError:
        failed_addresses.append(address)
        print(f'API call failed for index {i}')
# Out:
# API call successful for index 0
# API call successful for index 1
# API call successful for index 2
# API call successful for index 3
# API call successful for index 4
# API call successful for index 5
# API call successful for index 6
# API call successful for index 7
# API call successful for index 8
# API call successful for index 9
# API call successful for index 10
# API call successful for index 11
# API call successful for index 12
# API call successful for index 13
# API call successful for index 14
# API call successful for index 15
# API call successful for index 16
# API call successful for index 17
# API call successful for index 18
# API call successful for index 19
# API call successful for index 20
# API call successful for index 21
# API call successful for index 22
# API call successful for index 23
# API call successful for index 24
# API call successful for index 25
# API call successful for index 26
# API call failed for index 27
# API call successful for index 28
# API call successful for index 29
# API call successful for index 30
# API call successful for index 31
# API call successful for index 32
# API call successful for index 33
# API call successful for index 34
# API call successful for index 35
# API call successful for index 36
# API call successful for index 37
# API call successful for index 38
# API call successful for index 39
# API call successful for index 40
# API call failed for index 41
# API call successful for index 42
# API call successful for index 43
# API call successful for index 44
# API call successful for index 45
# API call successful for index 46
# API call successful for index 47
# API call successful for index 48
# API call successful for index 49
# API call successful for index 50
# API call failed for index 51
# API call successful for index 52
# API call successful for index 53
# API call successful for index 54
# API call successful for index 55
# API call successful for index 56
# API call successful for index 57
# API call successful for index 58
# API call successful for index 59
# API call successful for index 60
# API call successful for index 61
# API call successful for index 62
# API call failed for index 63
# API call successful for index 64
# API call successful for index 65
# API call successful for index 66
# API call successful for index 67
# API call successful for index 68
# API call failed for index 69
# API call successful for index 70
# API call successful for index 71
# API call successful for index 72
# API call successful for index 73
# API call failed for index 74
# API call successful for index 75
# API call successful for index 76
# API call successful for index 77
# API call successful for index 78
# API call successful for index 79
# API call successful for index 80
# API call successful for index 81
# API call successful for index 82
# API call successful for index 83
# API call successful for index 84
# API call successful for index 85
# API call successful for index 86
# API call successful for index 87
# API call successful for index 88
# API call successful for index 89
# API call successful for index 90
# API call successful for index 91
# API call successful for index 92
# API call successful for index 93
# API call successful for index 94
# API call successful for index 95
# API call successful for index 96
# API call failed for index 97
# API call successful for index 98
# API call successful for index 99
# API call successful for index 100
# API call successful for index 101
# API call successful for index 102
# API call successful for index 103
# API call successful for index 104
# API call successful for index 105
# API call successful for index 106
# API call successful for index 107
# API call successful for index 108
# API call successful for index 109
# API call successful for index 110
# API call successful for index 111
# API call successful for index 112
# API call successful for index 113
# API call successful for index 114
# API call successful for index 115
# API call successful for index 116
# API call successful for index 117
# API call successful for index 118
# API call successful for index 119
# API call successful for index 120
# API call successful for index 121
# API call successful for index 122
# API call successful for index 123
# API call successful for index 124
# API call successful for index 125
# API call successful for index 126
# API call successful for index 127
# API call failed for index 128
# API call successful for index 129
# API call successful for index 130
# API call successful for index 131
# API call successful for index 132

# %%
#API call for third list of addresses

for i in range(0, len(clean_add_3)):
    address = clean_add_3[i]
    address_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={address}&filter=place:{toronto_place_id}&format=json&apiKey={geoapify_key}"
    address_response = requests.get(address_url).json()
    try:
        latitude = address_response['results'][0]['lat']
        longitude = address_response['results'][0]['lon']
        coords = [longitude, latitude]
        clean_dict[address] = coords
        print(f'API call successful for index {i}')
    except IndexError:
        failed_addresses.append(address)
        print(f'API call failed for index {i}')
# Out:
# API call successful for index 0
# API call successful for index 1
# API call successful for index 2
# API call successful for index 3
# API call successful for index 4
# API call successful for index 5
# API call successful for index 6
# API call successful for index 7
# API call successful for index 8
# API call successful for index 9
# API call failed for index 10
# API call successful for index 11
# API call successful for index 12
# API call successful for index 13
# API call successful for index 14
# API call successful for index 15
# API call successful for index 16
# API call failed for index 17
# API call successful for index 18
# API call successful for index 19
# API call successful for index 20
# API call successful for index 21
# API call successful for index 22
# API call successful for index 23
# API call successful for index 24
# API call failed for index 25
# API call successful for index 26
# API call failed for index 27
# API call successful for index 28
# API call successful for index 29
# API call successful for index 30
# API call failed for index 31
# API call successful for index 32
# API call successful for index 33
# API call failed for index 34
# API call successful for index 35
# API call successful for index 36
# API call failed for index 37
# API call failed for index 38
# API call successful for index 39
# API call failed for index 40
# API call successful for index 41
# API call successful for index 42
# API call failed for index 43
# API call successful for index 44
# API call successful for index 45
# API call successful for index 46
# API call successful for index 47
# API call successful for index 48
# API call successful for index 49
# API call successful for index 50
# API call successful for index 51
# API call failed for index 52
# API call failed for index 53
# API call successful for index 54
# API call failed for index 55
# API call successful for index 56
# API call failed for index 57
# API call successful for index 58
# API call successful for index 59
# API call successful for index 60
# API call successful for index 61
# API call failed for index 62
# API call successful for index 63
# API call successful for index 64
# API call successful for index 65
# API call successful for index 66
# API call successful for index 67
# API call successful for index 68
# API call successful for index 69
# API call successful for index 70
# API call successful for index 71
# API call successful for index 72
# API call successful for index 73
# API call successful for index 74
# API call successful for index 75
# API call successful for index 76
# API call successful for index 77
# API call successful for index 78
# API call successful for index 79
# API call successful for index 80
# API call successful for index 81
# API call successful for index 82
# API call successful for index 83
# API call successful for index 84
# API call successful for index 85
# API call successful for index 86
# API call successful for index 87
# API call successful for index 88
# API call successful for index 89
# API call successful for index 90
# API call successful for index 91
# API call successful for index 92
# API call successful for index 93
# API call successful for index 94
# API call successful for index 95
# API call successful for index 96
# API call successful for index 97
# API call successful for index 98
# API call successful for index 99
# API call successful for index 100
# API call successful for index 101
# API call successful for index 102
# API call successful for index 103
# API call successful for index 104
# API call successful for index 105
# API call successful for index 106
# API call successful for index 107
# API call successful for index 108
# API call successful for index 109
# API call successful for index 110
# API call successful for index 111
# API call successful for index 112
# API call successful for index 113
# API call successful for index 114
# API call successful for index 115
# API call successful for index 116
# API call successful for index 117
# API call successful for index 118
# API call successful for index 119
# API call successful for index 120
# API call successful for index 121
# API call successful for index 122
# API call successful for index 123
# API call successful for index 124
# API call successful for index 125
# API call successful for index 126
# API call successful for index 127
# API call failed for index 128
# API call successful for index 129
# API call successful for index 130
# API call successful for index 131
# API call failed for index 132

# %%
#API call for fourth list of addresses

for i in range(0, len(clean_add_4)):
    address = clean_add_4[i]
    address_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={address}&filter=place:{toronto_place_id}&format=json&apiKey={geoapify_key}"
    address_response = requests.get(address_url).json()
    try:
        latitude = address_response['results'][0]['lat']
        longitude = address_response['results'][0]['lon']
        coords = [longitude, latitude]
        clean_dict[address] = coords
        print(f'API call successful for index {i}')
    except IndexError:
        failed_addresses.append(address)
        print(f'API call failed for index {i}')
# Out:
# API call successful for index 0
# API call successful for index 1
# API call successful for index 2
# API call successful for index 3
# API call successful for index 4
# API call successful for index 5
# API call successful for index 6
# API call successful for index 7
# API call successful for index 8
# API call successful for index 9
# API call successful for index 10
# API call successful for index 11
# API call successful for index 12
# API call successful for index 13
# API call successful for index 14
# API call successful for index 15
# API call successful for index 16
# API call successful for index 17
# API call successful for index 18
# API call successful for index 19
# API call successful for index 20
# API call successful for index 21
# API call successful for index 22
# API call successful for index 23
# API call successful for index 24
# API call successful for index 25
# API call successful for index 26
# API call successful for index 27
# API call successful for index 28
# API call successful for index 29
# API call successful for index 30
# API call successful for index 31
# API call successful for index 32
# API call successful for index 33
# API call successful for index 34
# API call successful for index 35
# API call successful for index 36
# API call failed for index 37
# API call successful for index 38
# API call successful for index 39
# API call successful for index 40
# API call successful for index 41
# API call successful for index 42
# API call successful for index 43
# API call successful for index 44
# API call successful for index 45
# API call successful for index 46
# API call successful for index 47
# API call successful for index 48
# API call successful for index 49
# API call successful for index 50
# API call failed for index 51
# API call failed for index 52
# API call successful for index 53
# API call successful for index 54
# API call successful for index 55
# API call successful for index 56
# API call successful for index 57
# API call successful for index 58
# API call successful for index 59
# API call successful for index 60
# API call failed for index 61
# API call successful for index 62
# API call successful for index 63
# API call successful for index 64
# API call failed for index 65
# API call successful for index 66
# API call successful for index 67
# API call successful for index 68
# API call successful for index 69
# API call successful for index 70
# API call successful for index 71
# API call successful for index 72
# API call successful for index 73
# API call successful for index 74
# API call successful for index 75
# API call successful for index 76
# API call successful for index 77
# API call successful for index 78
# API call successful for index 79
# API call successful for index 80
# API call successful for index 81
# API call successful for index 82
# API call successful for index 83
# API call successful for index 84
# API call successful for index 85
# API call successful for index 86
# API call successful for index 87
# API call successful for index 88
# API call successful for index 89
# API call successful for index 90
# API call successful for index 91
# API call failed for index 92
# API call successful for index 93
# API call failed for index 94
# API call successful for index 95
# API call successful for index 96
# API call successful for index 97
# API call successful for index 98
# API call failed for index 99
# API call successful for index 100
# API call successful for index 101
# API call successful for index 102
# API call successful for index 103
# API call successful for index 104
# API call successful for index 105
# API call successful for index 106
# API call successful for index 107
# API call successful for index 108
# API call successful for index 109
# API call successful for index 110
# API call successful for index 111
# API call successful for index 112
# API call successful for index 113
# API call failed for index 114
# API call failed for index 115
# API call successful for index 116
# API call successful for index 117
# API call successful for index 118
# API call successful for index 119
# API call successful for index 120
# API call failed for index 121
# API call successful for index 122
# API call successful for index 123
# API call successful for index 124
# API call successful for index 125
# API call failed for index 126
# API call successful for index 127
# API call successful for index 128
# API call failed for index 129
# API call successful for index 130
# API call successful for index 131
# API call successful for index 132
# API call successful for index 133

# %%
#Add new column to the data frame with the coordinates from clean_dict for the corresponding address
df_all['new_col'] = df_all['Institution Address'].map(clean_dict).fillna('')

# %%
df_all = df_all.drop('Coordinates', axis = 1)
df_all.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  \
# 0          2016-12-31         2017-01-20        Inactive
# 1          2016-12-30         2017-01-04        Inactive
# 2          2016-12-30         2017-01-13        Inactive
# 3          2016-12-30         2017-01-20        Inactive
# 4          2016-12-30         2017-01-20        Inactive
#
#                                    new_col
# 0                [-79.1894286, 43.8029937]
# 1                [-79.3236782, 43.6896572]
# 2                [-79.2516534, 43.7543919]
# 3  [-79.27409672758621, 43.69413068275862]
# 4  [-79.38257754978882, 43.76690666292305]

# %%
df_all = df_all.rename(columns = {'new_col': 'Coordinates'})
df_all.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  \
# 0          2016-12-31         2017-01-20        Inactive
# 1          2016-12-30         2017-01-04        Inactive
# 2          2016-12-30         2017-01-13        Inactive
# 3          2016-12-30         2017-01-20        Inactive
# 4          2016-12-30         2017-01-20        Inactive
#
#                                Coordinates
# 0                [-79.1894286, 43.8029937]
# 1                [-79.3236782, 43.6896572]
# 2                [-79.2516534, 43.7543919]
# 3  [-79.27409672758621, 43.69413068275862]
# 4  [-79.38257754978882, 43.76690666292305]

# %%
#Create split DF with longitude and latitude
split = pd.DataFrame(df_all['Coordinates'].to_list(), columns = ['Longitude', 'Latitude'])
split.head()
# Out:
#    Longitude   Latitude
# 0 -79.189429  43.802994
# 1 -79.323678  43.689657
# 2 -79.251653  43.754392
# 3 -79.274097  43.694131
# 4 -79.382578  43.766907

# %%
#Use pd.concat to combine df_all and split DFs
final_df = pd.concat([df_all, split], axis = 1)
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/fannysigouin/Desktop/Data Bootcamp/Projects/Project 3/Project-3_Group-7/ETL/outbreaks_cleaning.ipynb Cell 33 line 2
#       <a href='vscode-notebook-cell:/Users/fannysigouin/Desktop/Data%20Bootcamp/Projects/Project%203/Project-3_Group-7/ETL/outbreaks_cleaning.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> #Use pd.concat to combine df_all and split DFs
# ----> <a href='vscode-notebook-cell:/Users/fannysigouin/Desktop/Data%20Bootcamp/Projects/Project%203/Project-3_Group-7/ETL/outbreaks_cleaning.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> final_df = pd.concat([df_all, split], axis = 1)
#       <a href='vscode-notebook-cell:/Users/fannysigouin/Desktop/Data%20Bootcamp/Projects/Project%203/Project-3_Group-7/ETL/outbreaks_cleaning.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> final_df.head()
#
# NameError: name 'df_all' is not defined

# %%
#Drop unnecessary Coordinates column
final_df = final_df.drop('Coordinates', axis = 1)
final_df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude   Latitude
# 0          2016-12-31         2017-01-20        Inactive -79.189429  43.802994
# 1          2016-12-30         2017-01-04        Inactive -79.323678  43.689657
# 2          2016-12-30         2017-01-13        Inactive -79.251653  43.754392
# 3          2016-12-30         2017-01-20        Inactive -79.274097  43.694131
# 4          2016-12-30         2017-01-20        Inactive -79.382578  43.766907

# %%
#Drop rows where coordinates are missing
final_df = final_df.dropna(subset = ['Longitude'])

# %%
#Export to csv file
final_df.to_csv('Resources/cleaned_outbreaks_with_coords.csv')

# %%
#Export to json file
final_df.to_json('../Outbreak Setting Viz/cleaned_data.json')

# %% [markdown]
# ## Create dataframes/CSV files for each visualization

# %%
#Graphing time series by season
df = pd.read_csv('Resources/cleaned_outbreaks_with_coords.csv')
df.head()
# Out:
#    Unnamed: 0                                   Institution Name  \
# 0           0                           Extendicare Rouge Valley
# 1           1                       Michael Garron Hospital - H6
# 2           2                             Bendale Acres - 3rd Fl
# 3           3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...
# 4           4                           Amica At Bayview Gardens
#
#    Institution Address     Outbreak Setting Type of Outbreak  \
# 0       551 Conlins Rd                 LTCH      Respiratory
# 1      825 Coxwell Ave  Hospital-Acute Care          Enteric
# 2  2920 Lawrence Ave E                 LTCH      Respiratory
# 3    3555 Danforth Ave                 LTCH      Respiratory
# 4           19 Rean Dr      Retirement Home      Respiratory
#
#                Causative Agent Date Outbreak Began Date Declared Over  \
# 0                  Influenza A          2016-12-31         2017-01-20
# 1               Norovirus-like          2016-12-30         2017-01-04
# 2  Respiratory syncytial virus          2016-12-30         2017-01-13
# 3              Metapneumovirus          2016-12-30         2017-01-20
# 4                  Influenza A          2016-12-30         2017-01-20
#
#   Outbreak Status  Longitude   Latitude
# 0        Inactive -79.189429  43.802994
# 1        Inactive -79.323678  43.689657
# 2        Inactive -79.251653  43.754392
# 3        Inactive -79.274097  43.694131
# 4        Inactive -79.382578  43.766907

# %%
df = df.drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude   Latitude
# 0          2016-12-31         2017-01-20        Inactive -79.189429  43.802994
# 1          2016-12-30         2017-01-04        Inactive -79.323678  43.689657
# 2          2016-12-30         2017-01-13        Inactive -79.251653  43.754392
# 3          2016-12-30         2017-01-20        Inactive -79.274097  43.694131
# 4          2016-12-30         2017-01-20        Inactive -79.382578  43.766907

# %%
#Change Date Outbreak Began and Date Outbreak Over to datetime objects
df['Date Outbreak Began'] = pd.to_datetime(df['Date Outbreak Began'], format = '%Y-%m-%d')
df['Date Declared Over'] = pd.to_datetime(df['Date Declared Over'], format = '%Y-%m-%d')
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude   Latitude
# 0          2016-12-31         2017-01-20        Inactive -79.189429  43.802994
# 1          2016-12-30         2017-01-04        Inactive -79.323678  43.689657
# 2          2016-12-30         2017-01-13        Inactive -79.251653  43.754392
# 3          2016-12-30         2017-01-20        Inactive -79.274097  43.694131
# 4          2016-12-30         2017-01-20        Inactive -79.382578  43.766907

# %%
#Add columns for year and month
df['Outbreak Year'] = df['Date Outbreak Began'].dt.strftime('%Y')
df['Outbreak Month'] = df['Date Outbreak Began'].dt.strftime('%m')
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude  \
# 0          2016-12-31         2017-01-20        Inactive -79.189429
# 1          2016-12-30         2017-01-04        Inactive -79.323678
# 2          2016-12-30         2017-01-13        Inactive -79.251653
# 3          2016-12-30         2017-01-20        Inactive -79.274097
# 4          2016-12-30         2017-01-20        Inactive -79.382578
#
#     Latitude Outbreak Year Outbreak Month
# 0  43.802994          2016             12
# 1  43.689657          2016             12
# 2  43.754392          2016             12
# 3  43.694131          2016             12
# 4  43.766907          2016             12

# %%
#Convert int month to name month
df['Outbreak Month'] = pd.to_datetime(df['Outbreak Month'], format='%m').dt.month_name()
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude  \
# 0          2016-12-31         2017-01-20        Inactive -79.189429
# 1          2016-12-30         2017-01-04        Inactive -79.323678
# 2          2016-12-30         2017-01-13        Inactive -79.251653
# 3          2016-12-30         2017-01-20        Inactive -79.274097
# 4          2016-12-30         2017-01-20        Inactive -79.382578
#
#     Latitude Outbreak Year Outbreak Month
# 0  43.802994          2016       December
# 1  43.689657          2016       December
# 2  43.754392          2016       December
# 3  43.694131          2016       December
# 4  43.766907          2016       December

# %%
#Create dictionary to map seasons
seasons_dict = {'January': 'Winter', 
                'February': 'Winter', 
                'March': 'Spring', 
                'April': 'Spring', 
                'May': 'Spring', 
                'June': 'Summer',
                'July': 'Summer',
                'August': 'Summer',
                'September': 'Fall',
                'October': 'Fall',
                'November': 'Fall',
                'December': 'Winter'}

#Use .apply with lambda x to add a column to df for the season
df['Outbreak Season'] = df['Outbreak Month'].apply(lambda x: seasons_dict[x])
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude  \
# 0          2016-12-31         2017-01-20        Inactive -79.189429
# 1          2016-12-30         2017-01-04        Inactive -79.323678
# 2          2016-12-30         2017-01-13        Inactive -79.251653
# 3          2016-12-30         2017-01-20        Inactive -79.274097
# 4          2016-12-30         2017-01-20        Inactive -79.382578
#
#     Latitude Outbreak Year Outbreak Month Outbreak Season
# 0  43.802994          2016       December          Winter
# 1  43.689657          2016       December          Winter
# 2  43.754392          2016       December          Winter
# 3  43.694131          2016       December          Winter
# 4  43.766907          2016       December          Winter

# %%
df.to_csv('Resources/outbreaks.csv')

# %%
#Group DF by outbreak season and get count of outbreaks for all years
all_seasons = df.groupby('Outbreak Season', as_index = False)['Institution Name'].count()
all_seasons['Outbreak Year'] = 'All Years'
all_seasons = all_seasons[['Outbreak Year', 'Outbreak Season', 'Institution Name']]
all_seasons
# Out:
#   Outbreak Year Outbreak Season  Institution Name
# 0     All Years            Fall               970
# 1     All Years          Spring              1056
# 2     All Years          Summer               603
# 3     All Years          Winter              1530

# %%
#Group DF by year and season and get the count of outbreaks
grouped_seasons = df.groupby(['Outbreak Year', 'Outbreak Season'], as_index = False)['Institution Name'].count()
grouped_seasons
# Out:
#    Outbreak Year Outbreak Season  Institution Name
# 0           2016            Fall                46
# 1           2016          Spring                76
# 2           2016          Summer                27
# 3           2016          Winter               109
# 4           2017            Fall                36
# 5           2017          Spring                74
# 6           2017          Summer                43
# 7           2017          Winter               196
# 8           2018            Fall                51
# 9           2018          Spring               122
# 10          2018          Summer                30
# 11          2018          Winter               220
# 12          2019            Fall                37
# 13          2019          Spring                92
# 14          2019          Summer                39
# 15          2019          Winter               138
# 16          2020            Fall               123
# 17          2020          Spring               186
# 18          2020          Summer                35
# 19          2020          Winter               167
# 20          2021            Fall                29
# 21          2021          Spring                76
# 22          2021          Summer                18
# 23          2021          Winter               234
# 24          2022            Fall               323
# 25          2022          Spring               226
# 26          2022          Summer               268
# 27          2022          Winter               268
# 28          2023            Fall               325
# 29          2023          Spring               204
# 30          2023          Summer               143
# 31          2023          Winter               198

# %%
grouped_seasons_all = pd.concat([all_seasons, grouped_seasons], axis = 0, ignore_index = True)
grouped_seasons_all
# Out:
#    Outbreak Year Outbreak Season  Institution Name
# 0      All Years            Fall               970
# 1      All Years          Spring              1056
# 2      All Years          Summer               603
# 3      All Years          Winter              1530
# 4           2016            Fall                46
# 5           2016          Spring                76
# 6           2016          Summer                27
# 7           2016          Winter               109
# 8           2017            Fall                36
# 9           2017          Spring                74
# 10          2017          Summer                43
# 11          2017          Winter               196
# 12          2018            Fall                51
# 13          2018          Spring               122
# 14          2018          Summer                30
# 15          2018          Winter               220
# 16          2019            Fall                37
# 17          2019          Spring                92
# 18          2019          Summer                39
# 19          2019          Winter               138
# 20          2020            Fall               123
# 21          2020          Spring               186
# 22          2020          Summer                35
# 23          2020          Winter               167
# 24          2021            Fall                29
# 25          2021          Spring                76
# 26          2021          Summer                18
# 27          2021          Winter               234
# 28          2022            Fall               323
# 29          2022          Spring               226
# 30          2022          Summer               268
# 31          2022          Winter               268
# 32          2023            Fall               325
# 33          2023          Spring               204
# 34          2023          Summer               143
# 35          2023          Winter               198

# %%
#Export to csv
grouped_seasons_all.to_csv('Resources/outbreak_seasons_all_years.csv', index = False)

# %%
#Export grouped_seasons to CSV file
grouped_seasons.to_csv('Resources/outbreaks_by_year_season.csv')

# %%
#Outbreaks by outbreak setting
#Group by year and outbreak setting then get the count
outbreak_setting_by_year = df.groupby(['Outbreak Year', 'Outbreak Setting'], as_index = False)['Institution Name'].count()
outbreak_setting_by_year
# Out:
#    Outbreak Year       Outbreak Setting  Institution Name
# 0           2016    Hospital-Acute Care                28
# 1           2016  Hospital-Chronic Care                37
# 2           2016                   LTCH               153
# 3           2016        Retirement Home                39
# 4           2016                Shelter                 1
# 5           2017    Hospital-Acute Care                36
# 6           2017  Hospital-Chronic Care                27
# 7           2017   Hospital-Psychiatric                 2
# 8           2017                   LTCH               215
# 9           2017        Retirement Home                69
# 10          2018    Hospital-Acute Care                45
# 11          2018  Hospital-Chronic Care                42
# 12          2018   Hospital-Psychiatric                 6
# 13          2018                   LTCH               258
# 14          2018        Retirement Home                70
# 15          2018                Shelter                 2
# 16          2019    Hospital-Acute Care                39
# 17          2019  Hospital-Chronic Care                26
# 18          2019   Hospital-Psychiatric                 4
# 19          2019                   LTCH               198
# 20          2019        Retirement Home                39
# 21          2020    Hospital-Acute Care                78
# 22          2020  Hospital-Chronic Care                44
# 23          2020   Hospital-Psychiatric                 7
# 24          2020                   LTCH               295
# 25          2020        Retirement Home                87
# 26          2021    Hospital-Acute Care                85
# 27          2021  Hospital-Chronic Care                46
# 28          2021   Hospital-Psychiatric                 3
# 29          2021                   LTCH               173
# 30          2021        Retirement Home                50
# 31          2022    Hospital-Acute Care               231
# 32          2022  Hospital-Chronic Care               171
# 33          2022   Hospital-Psychiatric                13
# 34          2022                   LTCH               462
# 35          2022        Retirement Home               199
# 36          2022      Transitional Care                 9
# 37          2023    Hospital-Acute Care                88
# 38          2023  Hospital-Chronic Care               102
# 39          2023   Hospital-Psychiatric                14
# 40          2023                   LTCH               500
# 41          2023        Retirement Home               153
# 42          2023      Transitional Care                13

# %%
#Export to csv
outbreak_setting_by_year.to_csv('Resources/outbreak_setting_by_year.csv')

# %%
outbreak_setting_all = df.groupby('Outbreak Setting', as_index = False)['Institution Name'].count()
outbreak_setting_all
# Out:
#         Outbreak Setting  Institution Name
# 0    Hospital-Acute Care               630
# 1  Hospital-Chronic Care               495
# 2   Hospital-Psychiatric                49
# 3                   LTCH              2254
# 4        Retirement Home               706
# 5                Shelter                 3
# 6      Transitional Care                22

# %%
outbreak_setting_all['Outbreak Year'] = 'All Years'
outbreak_setting_all = outbreak_setting_all[['Outbreak Year', 'Outbreak Setting', 'Institution Name']]
outbreak_setting_all
# Out:
#   Outbreak Year       Outbreak Setting  Institution Name
# 0     All Years    Hospital-Acute Care               630
# 1     All Years  Hospital-Chronic Care               495
# 2     All Years   Hospital-Psychiatric                49
# 3     All Years                   LTCH              2254
# 4     All Years        Retirement Home               706
# 5     All Years                Shelter                 3
# 6     All Years      Transitional Care                22

# %%
outbreak_settings = pd.concat([outbreak_setting_by_year, outbreak_setting_all], axis = 0, ignore_index = True)
outbreak_settings
# Out:
#    Outbreak Year       Outbreak Setting  Institution Name
# 0           2016    Hospital-Acute Care                28
# 1           2016  Hospital-Chronic Care                37
# 2           2016                   LTCH               153
# 3           2016        Retirement Home                39
# 4           2016                Shelter                 1
# 5           2017    Hospital-Acute Care                36
# 6           2017  Hospital-Chronic Care                27
# 7           2017   Hospital-Psychiatric                 2
# 8           2017                   LTCH               215
# 9           2017        Retirement Home                69
# 10          2018    Hospital-Acute Care                45
# 11          2018  Hospital-Chronic Care                42
# 12          2018   Hospital-Psychiatric                 6
# 13          2018                   LTCH               258
# 14          2018        Retirement Home                70
# 15          2018                Shelter                 2
# 16          2019    Hospital-Acute Care                39
# 17          2019  Hospital-Chronic Care                26
# 18          2019   Hospital-Psychiatric                 4
# 19          2019                   LTCH               198
# 20          2019        Retirement Home                39
# 21          2020    Hospital-Acute Care                78
# 22          2020  Hospital-Chronic Care                44
# 23          2020   Hospital-Psychiatric                 7
# 24          2020                   LTCH               295
# 25          2020        Retirement Home                87
# 26          2021    Hospital-Acute Care                85
# 27          2021  Hospital-Chronic Care                46
# 28          2021   Hospital-Psychiatric                 3
# 29          2021                   LTCH               173
# 30          2021        Retirement Home                50
# 31          2022    Hospital-Acute Care               231
# 32          2022  Hospital-Chronic Care               171
# 33          2022   Hospital-Psychiatric                13
# 34          2022                   LTCH               462
# 35          2022        Retirement Home               199
# 36          2022      Transitional Care                 9
# 37          2023    Hospital-Acute Care                88
# 38          2023  Hospital-Chronic Care               102
# 39          2023   Hospital-Psychiatric                14
# 40          2023                   LTCH               500
# 41          2023        Retirement Home               153
# 42          2023      Transitional Care                13
# 43     All Years    Hospital-Acute Care               630
# 44     All Years  Hospital-Chronic Care               495
# 45     All Years   Hospital-Psychiatric                49
# 46     All Years                   LTCH              2254
# 47     All Years        Retirement Home               706
# 48     All Years                Shelter                 3
# 49     All Years      Transitional Care                22

# %%
#Export to csv
outbreak_settings.to_csv('Resources/outbreak_settings.csv', index = False)

# %%
#Export to csv
outbreak_setting_all.to_csv('Resources/outbreak_setting_all_years.csv')

# %%
#Average outbreak length by institution
#Add column to DF for outbreak duration
df['Outbreak Duration'] = df['Date Declared Over'] - df['Date Outbreak Began']
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude  \
# 0          2016-12-31         2017-01-20        Inactive -79.189429
# 1          2016-12-30         2017-01-04        Inactive -79.323678
# 2          2016-12-30         2017-01-13        Inactive -79.251653
# 3          2016-12-30         2017-01-20        Inactive -79.274097
# 4          2016-12-30         2017-01-20        Inactive -79.382578
#
#     Latitude Outbreak Year Outbreak Month Outbreak Season Outbreak Duration
# 0  43.802994          2016       December          Winter           20 days
# 1  43.689657          2016       December          Winter            5 days
# 2  43.754392          2016       December          Winter           14 days
# 3  43.694131          2016       December          Winter           21 days
# 4  43.766907          2016       December          Winter           21 days

# %%
#Extract just the institution name into a new column
df['Extracted Institution Name'] = df['Institution Name'].str.split(' - ').str[0]
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude  \
# 0          2016-12-31         2017-01-20        Inactive -79.189429
# 1          2016-12-30         2017-01-04        Inactive -79.323678
# 2          2016-12-30         2017-01-13        Inactive -79.251653
# 3          2016-12-30         2017-01-20        Inactive -79.274097
# 4          2016-12-30         2017-01-20        Inactive -79.382578
#
#     Latitude Outbreak Year Outbreak Month Outbreak Season Outbreak Duration  \
# 0  43.802994          2016       December          Winter           20 days
# 1  43.689657          2016       December          Winter            5 days
# 2  43.754392          2016       December          Winter           14 days
# 3  43.694131          2016       December          Winter           21 days
# 4  43.766907          2016       December          Winter           21 days
#
#   Extracted Institution Name
# 0   Extendicare Rouge Valley
# 1    Michael Garron Hospital
# 2              Bendale Acres
# 3            Chester Village
# 4   Amica At Bayview Gardens

# %%
df['Extracted Institution Name'] = df['Extracted Institution Name'].str.split(' -').str[0]
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude  \
# 0          2016-12-31         2017-01-20        Inactive -79.189429
# 1          2016-12-30         2017-01-04        Inactive -79.323678
# 2          2016-12-30         2017-01-13        Inactive -79.251653
# 3          2016-12-30         2017-01-20        Inactive -79.274097
# 4          2016-12-30         2017-01-20        Inactive -79.382578
#
#     Latitude Outbreak Year Outbreak Month Outbreak Season Outbreak Duration  \
# 0  43.802994          2016       December          Winter           20 days
# 1  43.689657          2016       December          Winter            5 days
# 2  43.754392          2016       December          Winter           14 days
# 3  43.694131          2016       December          Winter           21 days
# 4  43.766907          2016       December          Winter           21 days
#
#   Extracted Institution Name
# 0   Extendicare Rouge Valley
# 1    Michael Garron Hospital
# 2              Bendale Acres
# 3            Chester Village
# 4   Amica At Bayview Gardens

# %%
df['Extracted Institution Name'] = df['Extracted Institution Name'].str.split(' -').str[0]
df.head()
# Out:
# Sunnybrook Health Sciences Centre      186
# Unity Health Toronto                   168
# University Health Network               99
# West Park Healthcare Centre             81
# Scarborough Health Network              80
#                                       ...
# Midland Gardens Care Community Ltch      1
# City Of Toronto ? Cummer Lodge           1
# Uhn                                      1
# Trilogy Long Term Care                   1
# Villa Colombo Homes For The Aged         1
# Name: Extracted Institution Name, Length: 511, dtype: int64

# %%
df['Extracted Institution Name'] = df['Extracted Institution Name'].str.split('- ').str[0]
df.head()
# Out:
#                                     Institution Name  Institution Address  \
# 0                           Extendicare Rouge Valley       551 Conlins Rd
# 1                       Michael Garron Hospital - H6      825 Coxwell Ave
# 2                             Bendale Acres - 3rd Fl  2920 Lawrence Ave E
# 3  Chester Village - 3rd Fl - Ruby & 4th Fl - Eme...    3555 Danforth Ave
# 4                           Amica At Bayview Gardens           19 Rean Dr
#
#       Outbreak Setting Type of Outbreak              Causative Agent  \
# 0                 LTCH      Respiratory                  Influenza A
# 1  Hospital-Acute Care          Enteric               Norovirus-like
# 2                 LTCH      Respiratory  Respiratory syncytial virus
# 3                 LTCH      Respiratory              Metapneumovirus
# 4      Retirement Home      Respiratory                  Influenza A
#
#   Date Outbreak Began Date Declared Over Outbreak Status  Longitude  \
# 0          2016-12-31         2017-01-20        Inactive -79.189429
# 1          2016-12-30         2017-01-04        Inactive -79.323678
# 2          2016-12-30         2017-01-13        Inactive -79.251653
# 3          2016-12-30         2017-01-20        Inactive -79.274097
# 4          2016-12-30         2017-01-20        Inactive -79.382578
#
#     Latitude Outbreak Year Outbreak Month Outbreak Season Outbreak Duration  \
# 0  43.802994          2016       December          Winter           20 days
# 1  43.689657          2016       December          Winter            5 days
# 2  43.754392          2016       December          Winter           14 days
# 3  43.694131          2016       December          Winter           21 days
# 4  43.766907          2016       December          Winter           21 days
#
#   Extracted Institution Name
# 0   Extendicare Rouge Valley
# 1    Michael Garron Hospital
# 2              Bendale Acres
# 3            Chester Village
# 4   Amica At Bayview Gardens

# %%
#Group by the extracted institution name and get the average outbreak duration
inst_outbreak_duration = df.groupby('Extracted Institution Name', as_index = False)['Outbreak Duration'].mean()
inst_outbreak_duration
# Out:
#                         Extracted Institution Name Outbreak Duration
# 0                                                   38 days 00:00:00
# 1                                             1321  17 days 00:00:00
# 2                                 147 Elder Street  16 days 00:00:00
# 3           Advent Forestview Retirement Residence  16 days 16:00:00
# 4                      Advent Valleyview Residence  37 days 00:00:00
# ..                                             ...               ...
# 495              Yee Hong Centre Scarborough Finch  11 days 00:00:00
# 496             Yee Hong Centre for Geriatric Care  13 days 12:00:00
# 497     Yee Hong Centre for Geriatric Care (Finch)  21 days 00:00:00
# 498  Yee Hong Centre for Geriatric Care (McNicoll)  11 days 00:00:00
# 499                                 Yee Hong Finch  11 days 00:00:00
#
# [500 rows x 2 columns]

# %%
inst_outbreak_duration['Outbreak Duration'] = inst_outbreak_duration['Outbreak Duration'].round('D')
inst_outbreak_duration
# Out:
#                         Extracted Institution Name Outbreak Duration
# 0                                                            38 days
# 1                                             1321           17 days
# 2                                 147 Elder Street           16 days
# 3           Advent Forestview Retirement Residence           17 days
# 4                      Advent Valleyview Residence           37 days
# ..                                             ...               ...
# 495              Yee Hong Centre Scarborough Finch           11 days
# 496             Yee Hong Centre for Geriatric Care           14 days
# 497     Yee Hong Centre for Geriatric Care (Finch)           21 days
# 498  Yee Hong Centre for Geriatric Care (McNicoll)           11 days
# 499                                 Yee Hong Finch           11 days
#
# [500 rows x 2 columns]

# %%
inst_outbreak_duration = inst_outbreak_duration.drop(index = [0, 1])
inst_outbreak_duration = inst_outbreak_duration.reset_index(drop = True)
inst_outbreak_duration.head()
# Out:
#                Extracted Institution Name Outbreak Duration
# 0                        147 Elder Street           16 days
# 1  Advent Forestview Retirement Residence           17 days
# 2             Advent Valleyview Residence           37 days
# 3            Alexis Lodge Retirement Home           25 days
# 4       Alexis Lodge Retirement Residence           19 days

# %%
#Sort in descending order
inst_outbreak_duration = inst_outbreak_duration.sort_values(by = 'Outbreak Duration', ascending = False)
inst_outbreak_duration.head()
# Out:
#                Extracted Institution Name Outbreak Duration
# 320                          Seaton House          217 days
# 464         Village Of Humber Heights Ltc           97 days
# 270                  Parkland on Eglinton           84 days
# 219             Leaside Retirement Living           67 days
# 374  Terrace Gardens Retirement Residence           67 days

# %%
len(inst_outbreak_duration)
# Out:
# 498

# %%
inst_outbreak_duration = inst_outbreak_duration.dropna()
len(inst_outbreak_duration)
# Out:
# 497

# %%
#Slice first 10 institutions
top_10_inst_duration = inst_outbreak_duration.head(10).reset_index(drop = True)
top_10_inst_duration
# Out:
#                   Extracted Institution Name Outbreak Duration
# 0                               Seaton House          217 days
# 1              Village Of Humber Heights Ltc           97 days
# 2                       Parkland on Eglinton           84 days
# 3                  Leaside Retirement Living           67 days
# 4       Terrace Gardens Retirement Residence           67 days
# 5             Weston Terrace Care Community            66 days
# 6  Chartwell White Eagle Long Term Residence           63 days
# 7                   St George Care Community           62 days
# 8              The Rekai Centre at Wellesley           62 days
# 9                       Mackenzie Health Rcc           55 days

# %%
#Slice bottom 10 institutions
bottom_10_inst_duration = inst_outbreak_duration.tail(10).reset_index(drop = True)
bottom_10_inst_duration
# Out:
#             Extracted Institution Name Outbreak Duration
# 0             St Josephs Health Centre            6 days
# 1                                 TEHN            6 days
# 2                Marynard Nursing Home            6 days
# 3              St. Michael's Hospital             6 days
# 4   Baycrest Centre for Geriatric Care            5 days
# 5        Tapestry At Village Gate West            5 days
# 6       McCall Centre Interim LTC Unit            5 days
# 7  Amica Balmoral Club Retirement Home            3 days
# 8     Shepherd Terrace Retirement Home            1 days
# 9    Bendale Acres Long Term Care Home            1 days

# %%
#Export both DFs to csv
top_10_inst_duration.to_csv('Resources/top_10_outbreak_duration.csv')
bottom_10_inst_duration.to_csv('Resources/bottom_10_outbreak_duration.csv')

# %%
#Outbreaks by year
#Group DF by year
outbreaks_by_year = df.groupby('Outbreak Year')['Institution Name'].count()
outbreaks_by_year
# Out:
# Outbreak Year
# 2016     258
# 2017     349
# 2018     423
# 2019     306
# 2020     511
# 2021     357
# 2022    1085
# 2023     870
# Name: Institution Name, dtype: int64

# %%
#Group by type of outbreak and by year
outbreaks_by_year_type = df.groupby(['Type of Outbreak', 'Outbreak Year'])['Institution Name'].count()
outbreaks_by_year_type
# Out:
# Type of Outbreak  Outbreak Year
# Enteric           2016               40
#                   2017               63
#                   2018               77
#                   2019               54
#                   2020               33
#                   2021                8
#                   2022               23
#                   2023               41
# Other             2018                3
#                   2019                5
#                   2020                1
#                   2022                3
#                   2023                2
# Respiratory       2016              218
#                   2017              286
#                   2018              343
#                   2019              247
#                   2020              477
#                   2021              349
#                   2022             1059
#                   2023              827
# Name: Institution Name, dtype: int64

# %%
#Export both DFs to csv
outbreaks_by_year.to_csv('Resources/outbreaks_by_year.csv')
outbreaks_by_year_type.to_csv('Resources/outbreaks_by_year_type.csv')
